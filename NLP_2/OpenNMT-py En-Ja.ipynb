# %% [markdown]
# # OpenNMT-py によるニューラル機械翻訳演習
# OpenNMT-py というツールを用いて英日機械翻訳の演習を行います。
# Google Colaboratory は GPU を用いた実験ができるので、GPU を用いてニューラル機械翻訳の実験をしましょう。（「編集」→「ノートブックの設定」から「ハードウェアアクセラレータ」を GPU にしておいてください。以下、Python 3 で説明します。）
# データは田中コーパスという自由に使える対訳コーパスを使用します。翻訳結果を実際に見て評価する、ということも演習の目的です。

# %% [markdown]
# # OpenNMT-py の設定

# %% [markdown]
# ## ダウンロード

# %%
# !wget https://github.com/OpenNMT/OpenNMT-py/archive/master.zip

# %%
# !unzip master.zip

# %%
# cd OpenNMT-py-master

# %% [markdown]
# ## インストール

# %%
# !pip install OpenNMT-py

# %%
# %%bash
# cd /content
# wget https://github.com/OpenNMT/OpenNMT-py/archive/1.2.0.zip
# unzip 1.2.0.zip
# cd OpenNMT-py-1.2.0
# python setup.py install
# Out:
# Archive:  1.2.0.zip
# 60125c807d1cb18099a69dbfba699bcdf30560b1
#    creating: OpenNMT-py-1.2.0/
#   inflating: OpenNMT-py-1.2.0/.gitignore
#   inflating: OpenNMT-py-1.2.0/.travis.yml
#   inflating: OpenNMT-py-1.2.0/CHANGELOG.md
#   inflating: OpenNMT-py-1.2.0/CONTRIBUTING.md
#   inflating: OpenNMT-py-1.2.0/LICENSE.md
#   inflating: OpenNMT-py-1.2.0/README.md
#    creating: OpenNMT-py-1.2.0/available_models/
#   inflating: OpenNMT-py-1.2.0/available_models/example.conf.json
#    creating: OpenNMT-py-1.2.0/config/
#   inflating: OpenNMT-py-1.2.0/config/config-rnn-summarization.yml
#   inflating: OpenNMT-py-1.2.0/config/config-transformer-base-1GPU.yml
#   inflating: OpenNMT-py-1.2.0/config/config-transformer-base-4GPU.yml
#    creating: OpenNMT-py-1.2.0/data/
#   inflating: OpenNMT-py-1.2.0/data/README.md
#   inflating: OpenNMT-py-1.2.0/data/ggnnsrc.txt
#   inflating: OpenNMT-py-1.2.0/data/ggnnsrcvocab.txt
#   inflating: OpenNMT-py-1.2.0/data/ggnntgt.txt
#   inflating: OpenNMT-py-1.2.0/data/ggnntgtvocab.txt
#    creating: OpenNMT-py-1.2.0/data/morph/
#   inflating: OpenNMT-py-1.2.0/data/morph/src.train
#   inflating: OpenNMT-py-1.2.0/data/morph/src.valid
#   inflating: OpenNMT-py-1.2.0/data/morph/tgt.train
#   inflating: OpenNMT-py-1.2.0/data/morph/tgt.valid
#   inflating: OpenNMT-py-1.2.0/data/src-test.txt
#   inflating: OpenNMT-py-1.2.0/data/src-train.txt
#   inflating: OpenNMT-py-1.2.0/data/src-val.txt
#   inflating: OpenNMT-py-1.2.0/data/test_model2.src
#   inflating: OpenNMT-py-1.2.0/data/test_model2.tgt
#   inflating: OpenNMT-py-1.2.0/data/tgt-train.txt
#   inflating: OpenNMT-py-1.2.0/data/tgt-val.txt
#    creating: OpenNMT-py-1.2.0/docs/
#   inflating: OpenNMT-py-1.2.0/docs/Makefile
#   inflating: OpenNMT-py-1.2.0/docs/requirements.txt
#    creating: OpenNMT-py-1.2.0/docs/source/
#   inflating: OpenNMT-py-1.2.0/docs/source/CONTRIBUTING.md
#   inflating: OpenNMT-py-1.2.0/docs/source/FAQ.md
#   inflating: OpenNMT-py-1.2.0/docs/source/Library.ipynb
#   inflating: OpenNMT-py-1.2.0/docs/source/Library.md
#   inflating: OpenNMT-py-1.2.0/docs/source/Summarization.md
#    creating: OpenNMT-py-1.2.0/docs/source/_static/
#   inflating: OpenNMT-py-1.2.0/docs/source/_static/theme_overrides.css
#   inflating: OpenNMT-py-1.2.0/docs/source/conf.py
#   inflating: OpenNMT-py-1.2.0/docs/source/examples.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/extended.md
#   inflating: OpenNMT-py-1.2.0/docs/source/ggnn.md
#   inflating: OpenNMT-py-1.2.0/docs/source/im2text.md
#   inflating: OpenNMT-py-1.2.0/docs/source/index.md
#   inflating: OpenNMT-py-1.2.0/docs/source/index.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/main.md
#   inflating: OpenNMT-py-1.2.0/docs/source/modules.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/onmt.inputters.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/onmt.modules.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/onmt.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/onmt.translate.translation_server.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/onmt.translation.rst
#    creating: OpenNMT-py-1.2.0/docs/source/options/
#   inflating: OpenNMT-py-1.2.0/docs/source/options/preprocess.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/options/server.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/options/train.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/options/translate.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/quickstart.md
#   inflating: OpenNMT-py-1.2.0/docs/source/ref.rst
#   inflating: OpenNMT-py-1.2.0/docs/source/refs.bib
#   inflating: OpenNMT-py-1.2.0/docs/source/speech2text.md
#   inflating: OpenNMT-py-1.2.0/docs/source/vid2text.rst
#  extracting: OpenNMT-py-1.2.0/floyd.yml
#  extracting: OpenNMT-py-1.2.0/floyd_requirements.txt
#   inflating: OpenNMT-py-1.2.0/github_deploy_key_opennmt_opennmt_py.enc
#    creating: OpenNMT-py-1.2.0/onmt/
#   inflating: OpenNMT-py-1.2.0/onmt/__init__.py
#    creating: OpenNMT-py-1.2.0/onmt/bin/
#  extracting: OpenNMT-py-1.2.0/onmt/bin/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/bin/average_models.py
#   inflating: OpenNMT-py-1.2.0/onmt/bin/preprocess.py
#   inflating: OpenNMT-py-1.2.0/onmt/bin/release_model.py
#   inflating: OpenNMT-py-1.2.0/onmt/bin/server.py
#   inflating: OpenNMT-py-1.2.0/onmt/bin/train.py
#   inflating: OpenNMT-py-1.2.0/onmt/bin/translate.py
#    creating: OpenNMT-py-1.2.0/onmt/decoders/
#   inflating: OpenNMT-py-1.2.0/onmt/decoders/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/decoders/cnn_decoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/decoders/decoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/decoders/ensemble.py
#   inflating: OpenNMT-py-1.2.0/onmt/decoders/transformer.py
#    creating: OpenNMT-py-1.2.0/onmt/encoders/
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/audio_encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/cnn_encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/ggnn_encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/image_encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/mean_encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/rnn_encoder.py
#   inflating: OpenNMT-py-1.2.0/onmt/encoders/transformer.py
#    creating: OpenNMT-py-1.2.0/onmt/inputters/
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/audio_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/datareader_base.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/dataset_base.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/image_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/inputter.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/text_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/inputters/vec_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/model_builder.py
#    creating: OpenNMT-py-1.2.0/onmt/models/
#   inflating: OpenNMT-py-1.2.0/onmt/models/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/models/model.py
#   inflating: OpenNMT-py-1.2.0/onmt/models/model_saver.py
#   inflating: OpenNMT-py-1.2.0/onmt/models/sru.py
#   inflating: OpenNMT-py-1.2.0/onmt/models/stacked_rnn.py
#    creating: OpenNMT-py-1.2.0/onmt/modules/
#   inflating: OpenNMT-py-1.2.0/onmt/modules/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/average_attn.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/conv_multi_step_attention.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/copy_generator.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/embeddings.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/gate.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/global_attention.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/multi_headed_attn.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/position_ffn.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/source_noise.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/sparse_activations.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/sparse_losses.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/structured_attention.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/util_class.py
#   inflating: OpenNMT-py-1.2.0/onmt/modules/weight_norm.py
#   inflating: OpenNMT-py-1.2.0/onmt/opts.py
#    creating: OpenNMT-py-1.2.0/onmt/tests/
#  extracting: OpenNMT-py-1.2.0/onmt/tests/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/output_hyp.txt
#   inflating: OpenNMT-py-1.2.0/onmt/tests/pull_request_chk.sh
#   inflating: OpenNMT-py-1.2.0/onmt/tests/rebuild_test_models.sh
#   inflating: OpenNMT-py-1.2.0/onmt/tests/sample_glove.txt
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_attention.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_audio_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_beam_search.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_copy_generator.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_embeddings.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_greedy_search.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_image_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_model.pt
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_model2.pt
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_models.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_models.sh
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_preprocess.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_simple.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_structured_attention.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_text_dataset.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/test_translation_server.py
#   inflating: OpenNMT-py-1.2.0/onmt/tests/utils_for_tests.py
#   inflating: OpenNMT-py-1.2.0/onmt/train_single.py
#   inflating: OpenNMT-py-1.2.0/onmt/trainer.py
#    creating: OpenNMT-py-1.2.0/onmt/translate/
#   inflating: OpenNMT-py-1.2.0/onmt/translate/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/beam_search.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/decode_strategy.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/greedy_search.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/penalties.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/process_zh.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/translation.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/translation_server.py
#   inflating: OpenNMT-py-1.2.0/onmt/translate/translator.py
#    creating: OpenNMT-py-1.2.0/onmt/utils/
#   inflating: OpenNMT-py-1.2.0/onmt/utils/__init__.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/alignment.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/cnn_factory.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/distributed.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/earlystopping.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/logging.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/loss.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/misc.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/optimizers.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/parse.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/report_manager.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/rnn_factory.py
#   inflating: OpenNMT-py-1.2.0/onmt/utils/statistics.py
#   inflating: OpenNMT-py-1.2.0/preprocess.py
#   inflating: OpenNMT-py-1.2.0/requirements.opt.txt
#   inflating: OpenNMT-py-1.2.0/server.py
#   inflating: OpenNMT-py-1.2.0/setup.py
#    creating: OpenNMT-py-1.2.0/tools/
#   inflating: OpenNMT-py-1.2.0/tools/README.md
#   inflating: OpenNMT-py-1.2.0/tools/apply_bpe.py
#   inflating: OpenNMT-py-1.2.0/tools/average_models.py
#   inflating: OpenNMT-py-1.2.0/tools/bpe_pipeline.sh
#   inflating: OpenNMT-py-1.2.0/tools/create_vocabulary.py
#   inflating: OpenNMT-py-1.2.0/tools/detokenize.perl
#   inflating: OpenNMT-py-1.2.0/tools/embeddings_to_torch.py
#   inflating: OpenNMT-py-1.2.0/tools/extract_embeddings.py
#   inflating: OpenNMT-py-1.2.0/tools/learn_bpe.py
#   inflating: OpenNMT-py-1.2.0/tools/multi-bleu-detok.perl
#   inflating: OpenNMT-py-1.2.0/tools/multi-bleu.perl
#    creating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/README.txt
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.ca
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.cs
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.de
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.el
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.en
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.es
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.fi
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.fr
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.ga
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.hu
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.is
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.it
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.lt
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.lv
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.nl
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.pl
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.ro
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.ru
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.sk
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.sl
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.sv
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.ta
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.yue
#   inflating: OpenNMT-py-1.2.0/tools/nonbreaking_prefixes/nonbreaking_prefix.zh
#   inflating: OpenNMT-py-1.2.0/tools/release_model.py
#   inflating: OpenNMT-py-1.2.0/tools/test_rouge.py
#   inflating: OpenNMT-py-1.2.0/tools/tokenizer.perl
#   inflating: OpenNMT-py-1.2.0/tools/vid_feature_extractor.py
#   inflating: OpenNMT-py-1.2.0/train.py
#   inflating: OpenNMT-py-1.2.0/translate.py
# running install
# running bdist_egg
# running egg_info
# creating OpenNMT_py.egg-info
# writing OpenNMT_py.egg-info/PKG-INFO
# writing dependency_links to OpenNMT_py.egg-info/dependency_links.txt
# writing entry points to OpenNMT_py.egg-info/entry_points.txt
# writing requirements to OpenNMT_py.egg-info/requires.txt
# writing top-level names to OpenNMT_py.egg-info/top_level.txt
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# reading manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/onmt
# copying onmt/__init__.py -> build/lib/onmt
# copying onmt/trainer.py -> build/lib/onmt
# copying onmt/opts.py -> build/lib/onmt
# copying onmt/model_builder.py -> build/lib/onmt
# copying onmt/train_single.py -> build/lib/onmt
# creating build/lib/onmt/tests
# copying onmt/tests/test_simple.py -> build/lib/onmt/tests
# copying onmt/tests/__init__.py -> build/lib/onmt/tests
# copying onmt/tests/test_greedy_search.py -> build/lib/onmt/tests
# copying onmt/tests/test_beam_search.py -> build/lib/onmt/tests
# copying onmt/tests/test_copy_generator.py -> build/lib/onmt/tests
# copying onmt/tests/test_audio_dataset.py -> build/lib/onmt/tests
# copying onmt/tests/test_text_dataset.py -> build/lib/onmt/tests
# copying onmt/tests/test_structured_attention.py -> build/lib/onmt/tests
# copying onmt/tests/test_translation_server.py -> build/lib/onmt/tests
# copying onmt/tests/test_preprocess.py -> build/lib/onmt/tests
# copying onmt/tests/test_models.py -> build/lib/onmt/tests
# copying onmt/tests/utils_for_tests.py -> build/lib/onmt/tests
# copying onmt/tests/test_attention.py -> build/lib/onmt/tests
# copying onmt/tests/test_embeddings.py -> build/lib/onmt/tests
# copying onmt/tests/test_image_dataset.py -> build/lib/onmt/tests
# creating build/lib/onmt/inputters
# copying onmt/inputters/dataset_base.py -> build/lib/onmt/inputters
# copying onmt/inputters/image_dataset.py -> build/lib/onmt/inputters
# copying onmt/inputters/__init__.py -> build/lib/onmt/inputters
# copying onmt/inputters/vec_dataset.py -> build/lib/onmt/inputters
# copying onmt/inputters/datareader_base.py -> build/lib/onmt/inputters
# copying onmt/inputters/text_dataset.py -> build/lib/onmt/inputters
# copying onmt/inputters/audio_dataset.py -> build/lib/onmt/inputters
# copying onmt/inputters/inputter.py -> build/lib/onmt/inputters
# creating build/lib/onmt/translate
# copying onmt/translate/translator.py -> build/lib/onmt/translate
# copying onmt/translate/translation.py -> build/lib/onmt/translate
# copying onmt/translate/__init__.py -> build/lib/onmt/translate
# copying onmt/translate/decode_strategy.py -> build/lib/onmt/translate
# copying onmt/translate/process_zh.py -> build/lib/onmt/translate
# copying onmt/translate/greedy_search.py -> build/lib/onmt/translate
# copying onmt/translate/translation_server.py -> build/lib/onmt/translate
# copying onmt/translate/beam_search.py -> build/lib/onmt/translate
# copying onmt/translate/penalties.py -> build/lib/onmt/translate
# creating build/lib/onmt/modules
# copying onmt/modules/average_attn.py -> build/lib/onmt/modules
# copying onmt/modules/multi_headed_attn.py -> build/lib/onmt/modules
# copying onmt/modules/__init__.py -> build/lib/onmt/modules
# copying onmt/modules/embeddings.py -> build/lib/onmt/modules
# copying onmt/modules/structured_attention.py -> build/lib/onmt/modules
# copying onmt/modules/weight_norm.py -> build/lib/onmt/modules
# copying onmt/modules/sparse_activations.py -> build/lib/onmt/modules
# copying onmt/modules/copy_generator.py -> build/lib/onmt/modules
# copying onmt/modules/gate.py -> build/lib/onmt/modules
# copying onmt/modules/util_class.py -> build/lib/onmt/modules
# copying onmt/modules/sparse_losses.py -> build/lib/onmt/modules
# copying onmt/modules/position_ffn.py -> build/lib/onmt/modules
# copying onmt/modules/conv_multi_step_attention.py -> build/lib/onmt/modules
# copying onmt/modules/global_attention.py -> build/lib/onmt/modules
# copying onmt/modules/source_noise.py -> build/lib/onmt/modules
# creating build/lib/onmt/encoders
# copying onmt/encoders/__init__.py -> build/lib/onmt/encoders
# copying onmt/encoders/audio_encoder.py -> build/lib/onmt/encoders
# copying onmt/encoders/encoder.py -> build/lib/onmt/encoders
# copying onmt/encoders/cnn_encoder.py -> build/lib/onmt/encoders
# copying onmt/encoders/image_encoder.py -> build/lib/onmt/encoders
# copying onmt/encoders/rnn_encoder.py -> build/lib/onmt/encoders
# copying onmt/encoders/transformer.py -> build/lib/onmt/encoders
# copying onmt/encoders/ggnn_encoder.py -> build/lib/onmt/encoders
# copying onmt/encoders/mean_encoder.py -> build/lib/onmt/encoders
# creating build/lib/onmt/bin
# copying onmt/bin/translate.py -> build/lib/onmt/bin
# copying onmt/bin/__init__.py -> build/lib/onmt/bin
# copying onmt/bin/average_models.py -> build/lib/onmt/bin
# copying onmt/bin/preprocess.py -> build/lib/onmt/bin
# copying onmt/bin/train.py -> build/lib/onmt/bin
# copying onmt/bin/release_model.py -> build/lib/onmt/bin
# copying onmt/bin/server.py -> build/lib/onmt/bin
# creating build/lib/onmt/models
# copying onmt/models/__init__.py -> build/lib/onmt/models
# copying onmt/models/model_saver.py -> build/lib/onmt/models
# copying onmt/models/model.py -> build/lib/onmt/models
# copying onmt/models/sru.py -> build/lib/onmt/models
# copying onmt/models/stacked_rnn.py -> build/lib/onmt/models
# creating build/lib/onmt/decoders
# copying onmt/decoders/__init__.py -> build/lib/onmt/decoders
# copying onmt/decoders/ensemble.py -> build/lib/onmt/decoders
# copying onmt/decoders/cnn_decoder.py -> build/lib/onmt/decoders
# copying onmt/decoders/transformer.py -> build/lib/onmt/decoders
# copying onmt/decoders/decoder.py -> build/lib/onmt/decoders
# creating build/lib/onmt/utils
# copying onmt/utils/__init__.py -> build/lib/onmt/utils
# copying onmt/utils/optimizers.py -> build/lib/onmt/utils
# copying onmt/utils/loss.py -> build/lib/onmt/utils
# copying onmt/utils/report_manager.py -> build/lib/onmt/utils
# copying onmt/utils/earlystopping.py -> build/lib/onmt/utils
# copying onmt/utils/parse.py -> build/lib/onmt/utils
# copying onmt/utils/logging.py -> build/lib/onmt/utils
# copying onmt/utils/statistics.py -> build/lib/onmt/utils
# copying onmt/utils/distributed.py -> build/lib/onmt/utils
# copying onmt/utils/alignment.py -> build/lib/onmt/utils
# copying onmt/utils/misc.py -> build/lib/onmt/utils
# copying onmt/utils/cnn_factory.py -> build/lib/onmt/utils
# copying onmt/utils/rnn_factory.py -> build/lib/onmt/utils
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/onmt
# creating build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_simple.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/__init__.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_greedy_search.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_beam_search.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_copy_generator.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_audio_dataset.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_text_dataset.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_structured_attention.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_translation_server.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_preprocess.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_models.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/utils_for_tests.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_attention.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_embeddings.py -> build/bdist.linux-x86_64/egg/onmt/tests
# copying build/lib/onmt/tests/test_image_dataset.py -> build/bdist.linux-x86_64/egg/onmt/tests
# creating build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/dataset_base.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/image_dataset.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/__init__.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/vec_dataset.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/datareader_base.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/text_dataset.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/audio_dataset.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# copying build/lib/onmt/inputters/inputter.py -> build/bdist.linux-x86_64/egg/onmt/inputters
# creating build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/translator.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/translation.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/__init__.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/decode_strategy.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/process_zh.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/greedy_search.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/translation_server.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/beam_search.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/translate/penalties.py -> build/bdist.linux-x86_64/egg/onmt/translate
# copying build/lib/onmt/__init__.py -> build/bdist.linux-x86_64/egg/onmt
# copying build/lib/onmt/trainer.py -> build/bdist.linux-x86_64/egg/onmt
# copying build/lib/onmt/opts.py -> build/bdist.linux-x86_64/egg/onmt
# copying build/lib/onmt/model_builder.py -> build/bdist.linux-x86_64/egg/onmt
# creating build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/average_attn.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/multi_headed_attn.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/__init__.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/embeddings.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/structured_attention.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/weight_norm.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/sparse_activations.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/copy_generator.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/gate.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/util_class.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/sparse_losses.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/position_ffn.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/conv_multi_step_attention.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/global_attention.py -> build/bdist.linux-x86_64/egg/onmt/modules
# copying build/lib/onmt/modules/source_noise.py -> build/bdist.linux-x86_64/egg/onmt/modules
# creating build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/__init__.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/audio_encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/cnn_encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/image_encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/rnn_encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/transformer.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/ggnn_encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# copying build/lib/onmt/encoders/mean_encoder.py -> build/bdist.linux-x86_64/egg/onmt/encoders
# creating build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/translate.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/__init__.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/average_models.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/preprocess.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/train.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/release_model.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/bin/server.py -> build/bdist.linux-x86_64/egg/onmt/bin
# copying build/lib/onmt/train_single.py -> build/bdist.linux-x86_64/egg/onmt
# creating build/bdist.linux-x86_64/egg/onmt/models
# copying build/lib/onmt/models/__init__.py -> build/bdist.linux-x86_64/egg/onmt/models
# copying build/lib/onmt/models/model_saver.py -> build/bdist.linux-x86_64/egg/onmt/models
# copying build/lib/onmt/models/model.py -> build/bdist.linux-x86_64/egg/onmt/models
# copying build/lib/onmt/models/sru.py -> build/bdist.linux-x86_64/egg/onmt/models
# copying build/lib/onmt/models/stacked_rnn.py -> build/bdist.linux-x86_64/egg/onmt/models
# creating build/bdist.linux-x86_64/egg/onmt/decoders
# copying build/lib/onmt/decoders/__init__.py -> build/bdist.linux-x86_64/egg/onmt/decoders
# copying build/lib/onmt/decoders/ensemble.py -> build/bdist.linux-x86_64/egg/onmt/decoders
# copying build/lib/onmt/decoders/cnn_decoder.py -> build/bdist.linux-x86_64/egg/onmt/decoders
# copying build/lib/onmt/decoders/transformer.py -> build/bdist.linux-x86_64/egg/onmt/decoders
# copying build/lib/onmt/decoders/decoder.py -> build/bdist.linux-x86_64/egg/onmt/decoders
# creating build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/__init__.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/optimizers.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/loss.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/report_manager.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/earlystopping.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/parse.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/logging.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/statistics.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/distributed.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/alignment.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/misc.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/cnn_factory.py -> build/bdist.linux-x86_64/egg/onmt/utils
# copying build/lib/onmt/utils/rnn_factory.py -> build/bdist.linux-x86_64/egg/onmt/utils
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_simple.py to test_simple.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_greedy_search.py to test_greedy_search.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_beam_search.py to test_beam_search.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_copy_generator.py to test_copy_generator.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_audio_dataset.py to test_audio_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_text_dataset.py to test_text_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_structured_attention.py to test_structured_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_translation_server.py to test_translation_server.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_preprocess.py to test_preprocess.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_models.py to test_models.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/utils_for_tests.py to utils_for_tests.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_attention.py to test_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_embeddings.py to test_embeddings.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/tests/test_image_dataset.py to test_image_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/dataset_base.py to dataset_base.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/image_dataset.py to image_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/vec_dataset.py to vec_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/datareader_base.py to datareader_base.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/text_dataset.py to text_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/audio_dataset.py to audio_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/inputters/inputter.py to inputter.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/translator.py to translator.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/translation.py to translation.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/decode_strategy.py to decode_strategy.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/process_zh.py to process_zh.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/greedy_search.py to greedy_search.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/translation_server.py to translation_server.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/beam_search.py to beam_search.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/translate/penalties.py to penalties.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/trainer.py to trainer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/opts.py to opts.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/model_builder.py to model_builder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/average_attn.py to average_attn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/multi_headed_attn.py to multi_headed_attn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/embeddings.py to embeddings.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/structured_attention.py to structured_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/weight_norm.py to weight_norm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/sparse_activations.py to sparse_activations.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/copy_generator.py to copy_generator.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/gate.py to gate.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/util_class.py to util_class.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/sparse_losses.py to sparse_losses.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/position_ffn.py to position_ffn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/conv_multi_step_attention.py to conv_multi_step_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/global_attention.py to global_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/modules/source_noise.py to source_noise.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/audio_encoder.py to audio_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/encoder.py to encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/cnn_encoder.py to cnn_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/image_encoder.py to image_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/rnn_encoder.py to rnn_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/transformer.py to transformer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/ggnn_encoder.py to ggnn_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/encoders/mean_encoder.py to mean_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/translate.py to translate.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/average_models.py to average_models.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/preprocess.py to preprocess.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/train.py to train.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/release_model.py to release_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/bin/server.py to server.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/train_single.py to train_single.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/models/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/models/model_saver.py to model_saver.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/models/model.py to model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/models/sru.py to sru.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/models/stacked_rnn.py to stacked_rnn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/decoders/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/decoders/ensemble.py to ensemble.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/decoders/cnn_decoder.py to cnn_decoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/decoders/transformer.py to transformer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/decoders/decoder.py to decoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/optimizers.py to optimizers.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/loss.py to loss.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/report_manager.py to report_manager.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/earlystopping.py to earlystopping.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/parse.py to parse.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/logging.py to logging.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/statistics.py to statistics.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/distributed.py to distributed.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/alignment.py to alignment.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/misc.py to misc.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/cnn_factory.py to cnn_factory.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/onmt/utils/rnn_factory.py to rnn_factory.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenNMT_py.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenNMT_py.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenNMT_py.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenNMT_py.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenNMT_py.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying OpenNMT_py.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/OpenNMT_py-1.2.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing OpenNMT_py-1.2.0-py3.6.egg
# creating /usr/local/lib/python3.6/dist-packages/OpenNMT_py-1.2.0-py3.6.egg
# Extracting OpenNMT_py-1.2.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding OpenNMT-py 1.2.0 to easy-install.pth file
# Installing onmt_average_models script to /usr/local/bin
# Installing onmt_preprocess script to /usr/local/bin
# Installing onmt_release_model script to /usr/local/bin
# Installing onmt_server script to /usr/local/bin
# Installing onmt_train script to /usr/local/bin
# Installing onmt_translate script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/OpenNMT_py-1.2.0-py3.6.egg
# Processing dependencies for OpenNMT-py==1.2.0
# Searching for pyonmttok==1.*
# Reading https://pypi.org/simple/pyonmttok/
# Downloading https://files.pythonhosted.org/packages/f2/02/45433f86ff7dbccae319f4aff32187fa9e9c9c3204c9f7f7b07b5c9aa9dc/pyonmttok-1.23.0-cp36-cp36m-manylinux1_x86_64.whl#sha256=69803e14dcaaecfa0fc193bbb8a039670a38318deef5e25862ac4fe8e562143f
# Best match: pyonmttok 1.23.0
# Processing pyonmttok-1.23.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing pyonmttok-1.23.0-cp36-cp36m-manylinux1_x86_64.whl to /usr/local/lib/python3.6/dist-packages
# Adding pyonmttok 1.23.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/pyonmttok-1.23.0-py3.6-linux-x86_64.egg
# Searching for waitress
# Reading https://pypi.org/simple/waitress/
# Downloading https://files.pythonhosted.org/packages/92/6c/be1405c68906d327c2a16fa00a8741736096d25988b472f8dca31a0d9109/waitress-2.0.0b1-py3-none-any.whl#sha256=2dc8067126856346f126039f7b5dc5788fb90fc5171071f50bcf060e08043aef
# Best match: waitress 2.0.0b1
# Processing waitress-2.0.0b1-py3-none-any.whl
# Installing waitress-2.0.0b1-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding waitress 2.0.0b1 to easy-install.pth file
# Installing waitress-serve script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/waitress-2.0.0b1-py3.6.egg
# Searching for configargparse
# Reading https://pypi.org/simple/configargparse/
# Downloading https://files.pythonhosted.org/packages/bb/79/3045743bb26ca2e44a1d317c37395462bfed82dbbd38e69a3280b63696ce/ConfigArgParse-1.2.3.tar.gz#sha256=edd17be986d5c1ba2e307150b8e5f5107aba125f3574dddd02c85d5cdcfd37dc
# Best match: ConfigArgParse 1.2.3
# Processing ConfigArgParse-1.2.3.tar.gz
# Writing /tmp/easy_install-be2ovb83/ConfigArgParse-1.2.3/setup.cfg
# Running ConfigArgParse-1.2.3/setup.py -q bdist_egg --dist-dir /tmp/easy_install-be2ovb83/ConfigArgParse-1.2.3/egg-dist-tmp-umgdqcuw
# Moving ConfigArgParse-1.2.3-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding ConfigArgParse 1.2.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/ConfigArgParse-1.2.3-py3.6.egg
# Searching for torchtext==0.4.0
# Reading https://pypi.org/simple/torchtext/
# Downloading https://files.pythonhosted.org/packages/43/94/929d6bd236a4fb5c435982a7eb9730b78dcd8659acf328fd2ef9de85f483/torchtext-0.4.0-py3-none-any.whl#sha256=094520d9cd0af6a05368d9023fdc91dc038232bd9d128c7b548ec2200dba53ec
# Best match: torchtext 0.4.0
# Processing torchtext-0.4.0-py3-none-any.whl
# Installing torchtext-0.4.0-py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding torchtext 0.4.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/torchtext-0.4.0-py3.6.egg
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Flask==1.1.2
# Best match: Flask 1.1.2
# Adding Flask 1.1.2 to easy-install.pth file
# Installing flask script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorboard==2.4.1
# Best match: tensorboard 2.4.1
# Adding tensorboard 2.4.1 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for future==0.16.0
# Best match: future 0.16.0
# Adding future 0.16.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for torch==1.7.0+cu101
# Best match: torch 1.7.0+cu101
# Adding torch 1.7.0+cu101 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tqdm==4.41.1
# Best match: tqdm 4.41.1
# Adding tqdm 4.41.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Werkzeug==1.0.1
# Best match: Werkzeug 1.0.1
# Adding Werkzeug 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for click==7.1.2
# Best match: click 7.1.2
# Adding click 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for itsdangerous==1.1.0
# Best match: itsdangerous 1.1.0
# Adding itsdangerous 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Jinja2==2.11.2
# Best match: Jinja2 2.11.2
# Adding Jinja2 2.11.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Markdown==3.3.3
# Best match: Markdown 3.3.3
# Adding Markdown 3.3.3 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for google-auth-oauthlib==0.4.2
# Best match: google-auth-oauthlib 0.4.2
# Adding google-auth-oauthlib 0.4.2 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for protobuf==3.12.4
# Best match: protobuf 3.12.4
# Adding protobuf 3.12.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for grpcio==1.32.0
# Best match: grpcio 1.32.0
# Adding grpcio 1.32.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for absl-py==0.10.0
# Best match: absl-py 0.10.0
# Adding absl-py 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools
#  34000K .......... .......... .......... .......... .......... 97% 98.4M 0s
#  34050K .......... .......... .......... .......... .......... 98% 97.9M 0s
#  34100K .......... .......... .......... .......... .......... 98% 86.7M 0s
#  34150K .......... .......... .......... .......... .......... 98% 98.1M 0s
#  34200K .......... .......... .......... .......... .......... 98% 96.1M 0s
#  34250K .......... .......... .......... .......... .......... 98%  102M 0s
#  34300K .......... .......... .......... .......... .......... 98% 96.5M 0s
#  34350K .......... .......... .......... .......... .......... 98%  102M 0s
#  34400K .......... .......... .......... .......... .......... 99% 95.5M 0s
#  34450K .......... .......... .......... .......... .......... 99% 96.8M 0s
#  34500K .......... .......... .......... .......... .......... 99% 95.1M 0s
#  34550K .......... .......... .......... .......... .......... 99%  101M 0s
#  34600K .......... .......... .......... .......... .......... 99% 94.6M 0s
#  34650K .......... .......... .......... .......... .......... 99%  102M 0s
#  34700K .......... .......... .......... .......... ........  100% 95.8M=0.6s
#
# 2021-01-30 08:39:29 (57.2 MB/s) - ‘1.2.0.zip’ saved [35582731/35582731]
#
# zip_safe flag not set; analyzing archive contents...
# onmt.tests.__pycache__.test_audio_dataset.cpython-36: module references __file__
# onmt.tests.__pycache__.test_image_dataset.cpython-36: module references __file__
# onmt.tests.__pycache__.test_translation_server.cpython-36: module references __file__
# zip_safe flag not set; analyzing archive contents...

# %% [markdown]
# # 対訳データのインストールと前処理

# %% [markdown]
# ## 田中コーパス
# 田中コーパスというデータで翻訳実験を行います。日本の大学生が翻訳したデータです。そのうち適当な長さの5万文だけを抽出して実験しやすいようにしてくれたデータを用います。
# train.{ja,en}というのが学習データ、dev.{ja,en}というのが開発データ、test.{ja,en}というのがテストデータです。

# %%
cd OpenNMT-py-1.2.0/
# Out:
# /content/OpenNMT-py-1.2.0

# %%
# !git clone https://github.com/odashi/small_parallel_enja
# Out:
# Cloning into 'small_parallel_enja'...
# remote: Enumerating objects: 35, done.
# remote: Total 35 (delta 0), reused 0 (delta 0), pack-reused 35
# Unpacking objects: 100% (35/35), done.

# %%
ls small_parallel_enja
# Out:
# dev.en     train.en.000       train.en.vocab.all  train.ja.004
# dev.ja     train.en.001       train.ja            train.ja.vocab.4k
# README.md  train.en.002       train.ja.000        train.ja.vocab.all
# test.en    train.en.003       train.ja.001
# test.ja    train.en.004       train.ja.002
# train.en   train.en.vocab.4k  train.ja.003

# %% [markdown]
# ## データの前処理
# 日本語の単語分割と英語のtokenizationは済みです。onmt_preprocessというコマンドでデータの前処理をします。語彙テーブルを作り訓練データをOpenNMTように加工します。

# %%
# !onmt_preprocess -train_src small_parallel_enja/train.en -train_tgt small_parallel_enja/train.ja -valid_src small_parallel_enja/dev.en -valid_tgt small_parallel_enja/dev.ja -save_data data/tanaka
# Out:
# [2021-01-30 08:39:38,656 INFO] Extracting features...
# [2021-01-30 08:39:38,656 INFO]  * number of source features: 0.
# [2021-01-30 08:39:38,656 INFO]  * number of target features: 0.
# [2021-01-30 08:39:38,656 INFO] Building `Fields` object...
# [2021-01-30 08:39:38,656 INFO] Building & saving training data...
# [2021-01-30 08:39:38,715 INFO] Building shard 0.
# [2021-01-30 08:39:40,565 INFO]  * saving 0th train data shard to data/tanaka.train.0.pt.
# [2021-01-30 08:39:41,617 INFO]  * tgt vocab size: 8778.
# [2021-01-30 08:39:41,624 INFO]  * src vocab size: 6636.
# [2021-01-30 08:39:41,684 INFO] Building & saving validation data...
# [2021-01-30 08:39:41,712 INFO] Building shard 0.
# [2021-01-30 08:39:41,720 INFO]  * saving 0th valid data shard to data/tanaka.valid.0.pt.

# %%
ls data/
# Out:
# ggnnsrc.txt       morph/         src-val.txt        test_model2.src
# ggnnsrcvocab.txt  README.md      tanaka.train.0.pt  test_model2.tgt
# ggnntgt.txt       src-test.txt   tanaka.valid.0.pt  tgt-train.txt
# ggnntgtvocab.txt  src-train.txt  tanaka.vocab.pt    tgt-val.txt

# %% [markdown]
# # 注意型NMT

# %% [markdown]
# ## 学習
# onmt_train というコマンドで学習します。いくつかオプションがあるので、変えてみると挙動も変わります。
# --world_size で使う GPU の個数、--gpu_ranks で使う GPU を指定します（0スタートです）。指定しないと CPU になってしまいます。CPU は GPU の数十倍遅いです。
# --train_steps は学習するステップを指定します。20,000だとこのデータは20分くらいで学習できます。

# %%
# !onmt_train --help
# Out:
# usage: onmt_train [-h] [-config CONFIG] [-save_config SAVE_CONFIG]
#                   [--src_word_vec_size SRC_WORD_VEC_SIZE]
#                   [--tgt_word_vec_size TGT_WORD_VEC_SIZE]
#                   [--word_vec_size WORD_VEC_SIZE] [--share_decoder_embeddings]
#                   [--share_embeddings] [--position_encoding]
#                   [--feat_merge {concat,sum,mlp}]
#                   [--feat_vec_size FEAT_VEC_SIZE]
#                   [--feat_vec_exponent FEAT_VEC_EXPONENT]
#                   [--model_type {text,img,audio,vec}]
#                   [--model_dtype {fp32,fp16}]
#                   [--encoder_type {rnn,brnn,ggnn,mean,transformer,cnn}]
#                   [--decoder_type {rnn,transformer,cnn}] [--layers LAYERS]
#                   [--enc_layers ENC_LAYERS] [--dec_layers DEC_LAYERS]
#                   [--rnn_size RNN_SIZE] [--enc_rnn_size ENC_RNN_SIZE]
#                   [--dec_rnn_size DEC_RNN_SIZE]
#                   [--audio_enc_pooling AUDIO_ENC_POOLING]
#                   [--cnn_kernel_width CNN_KERNEL_WIDTH]
#                   [--input_feed INPUT_FEED] [--bridge]
#                   [--rnn_type {LSTM,GRU,SRU}] [--brnn]
#                   [--context_gate {source,target,both}]
#                   [--bridge_extra_node BRIDGE_EXTRA_NODE]
#                   [--bidir_edges BIDIR_EDGES] [--state_dim STATE_DIM]
#                   [--n_edge_types N_EDGE_TYPES] [--n_node N_NODE]
#                   [--n_steps N_STEPS] [--src_vocab SRC_VOCAB]
#                   [--global_attention {dot,general,mlp,none}]
#                   [--global_attention_function {softmax,sparsemax}]
#                   [--self_attn_type SELF_ATTN_TYPE]
#                   [--max_relative_positions MAX_RELATIVE_POSITIONS]
#                   [--heads HEADS] [--transformer_ff TRANSFORMER_FF]
#                   [--aan_useffn] [--lambda_align LAMBDA_ALIGN]
#                   [--alignment_layer ALIGNMENT_LAYER]
#                   [--alignment_heads ALIGNMENT_HEADS]
#                   [--full_context_alignment] [--copy_attn]
#                   [--copy_attn_type {dot,general,mlp,none}]
#                   [--generator_function {softmax,sparsemax}]
#                   [--copy_attn_force] [--reuse_copy_attn]
#                   [--copy_loss_by_seqlength] [--coverage_attn]
#                   [--lambda_coverage LAMBDA_COVERAGE]
#                   [--loss_scale LOSS_SCALE] [--apex_opt_level {O0,O1,O2,O3}]
#                   --data DATA [--data_ids DATA_IDS [DATA_IDS ...]]
#                   [--data_weights DATA_WEIGHTS [DATA_WEIGHTS ...]]
#                   [--data_to_noise DATA_TO_NOISE [DATA_TO_NOISE ...]]
#                   [--save_model SAVE_MODEL]
#                   [--save_checkpoint_steps SAVE_CHECKPOINT_STEPS]
#                   [--keep_checkpoint KEEP_CHECKPOINT]
#                   [--gpuid [GPUID [GPUID ...]]]
#                   [--gpu_ranks [GPU_RANKS [GPU_RANKS ...]]]
#                   [--world_size WORLD_SIZE] [--gpu_backend GPU_BACKEND]
#                   [--gpu_verbose_level GPU_VERBOSE_LEVEL]
#                   [--master_ip MASTER_IP] [--master_port MASTER_PORT]
#                   [--queue_size QUEUE_SIZE] [--seed SEED]
#                   [--param_init PARAM_INIT] [--param_init_glorot]
#                   [--train_from TRAIN_FROM]
#                   [--reset_optim {none,all,states,keep_states}]
#                   [--pre_word_vecs_enc PRE_WORD_VECS_ENC]
#                   [--pre_word_vecs_dec PRE_WORD_VECS_DEC]
#                   [--fix_word_vecs_enc] [--fix_word_vecs_dec]
#                   [--batch_size BATCH_SIZE]
#                   [--batch_size_multiple BATCH_SIZE_MULTIPLE]
#                   [--batch_type {sents,tokens}] [--pool_factor POOL_FACTOR]
#                   [--normalization {sents,tokens}]
#                   [--accum_count ACCUM_COUNT [ACCUM_COUNT ...]]
#                   [--accum_steps ACCUM_STEPS [ACCUM_STEPS ...]]
#                   [--valid_steps VALID_STEPS]
#                   [--valid_batch_size VALID_BATCH_SIZE]
#                   [--max_generator_batches MAX_GENERATOR_BATCHES]
#                   [--train_steps TRAIN_STEPS] [--single_pass]
#                   [--epochs EPOCHS] [--early_stopping EARLY_STOPPING]
#                   [--early_stopping_criteria [EARLY_STOPPING_CRITERIA [EARLY_STOPPING_CRITERIA ...]]]
#                   [--optim {sgd,adagrad,adadelta,adam,sparseadam,adafactor,fusedadam}]
#                   [--adagrad_accumulator_init ADAGRAD_ACCUMULATOR_INIT]
#                   [--max_grad_norm MAX_GRAD_NORM]
#                   [--dropout DROPOUT [DROPOUT ...]]
#                   [--attention_dropout ATTENTION_DROPOUT [ATTENTION_DROPOUT ...]]
#                   [--dropout_steps DROPOUT_STEPS [DROPOUT_STEPS ...]]
#                   [--truncated_decoder TRUNCATED_DECODER]
#                   [--adam_beta1 ADAM_BETA1] [--adam_beta2 ADAM_BETA2]
#                   [--label_smoothing LABEL_SMOOTHING]
#                   [--average_decay AVERAGE_DECAY]
#                   [--average_every AVERAGE_EVERY]
#                   [--src_noise {sen_shuffling,infilling,mask} [{sen_shuffling,infilling,mask} ...]]
#                   [--src_noise_prob SRC_NOISE_PROB [SRC_NOISE_PROB ...]]
#                   [--learning_rate LEARNING_RATE]
#                   [--learning_rate_decay LEARNING_RATE_DECAY]
#                   [--start_decay_steps START_DECAY_STEPS]
#                   [--decay_steps DECAY_STEPS]
#                   [--decay_method {noam,noamwd,rsqrt,none}]
#                   [--warmup_steps WARMUP_STEPS] [--report_every REPORT_EVERY]
#                   [--log_file LOG_FILE]
#                   [--log_file_level {CRITICAL,ERROR,WARNING,INFO,DEBUG,NOTSET,50,40,30,20,10,0}]
#                   [--exp_host EXP_HOST] [--exp EXP] [--tensorboard]
#                   [--tensorboard_log_dir TENSORBOARD_LOG_DIR]
#                   [--sample_rate SAMPLE_RATE] [--window_size WINDOW_SIZE]
#                   [--image_channel_size {3,1}]
#
# train.py Args that start with '--' (eg. --src_word_vec_size) can also be set
# in a config file (specified via -config). The config file uses YAML syntax and
# must represent a YAML 'mapping' (for details, see
# http://learn.getgrav.org/advanced/yaml). If an arg is specified in more than
# one place, then commandline values override config file values which override
# defaults.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -config CONFIG, --config CONFIG
#                         config file path (default: None)
#   -save_config SAVE_CONFIG, --save_config SAVE_CONFIG
#                         config file save path (default: None)
#
# Model-Embeddings:
#   --src_word_vec_size SRC_WORD_VEC_SIZE, -src_word_vec_size SRC_WORD_VEC_SIZE
#                         Word embedding size for src. (default: 500)
#   --tgt_word_vec_size TGT_WORD_VEC_SIZE, -tgt_word_vec_size TGT_WORD_VEC_SIZE
#                         Word embedding size for tgt. (default: 500)
#   --word_vec_size WORD_VEC_SIZE, -word_vec_size WORD_VEC_SIZE
#                         Word embedding size for src and tgt. (default: -1)
#   --share_decoder_embeddings, -share_decoder_embeddings
#                         Use a shared weight matrix for the input and output
#                         word embeddings in the decoder. (default: False)
#   --share_embeddings, -share_embeddings
#                         Share the word embeddings between encoder and decoder.
#                         Need to use shared dictionary for this option.
#                         (default: False)
#   --position_encoding, -position_encoding
#                         Use a sin to mark relative words positions. Necessary
#                         for non-RNN style models. (default: False)
#
# Model-Embedding Features:
#   --feat_merge {concat,sum,mlp}, -feat_merge {concat,sum,mlp}
#                         Merge action for incorporating features embeddings.
#                         Options [concat|sum|mlp]. (default: concat)
#   --feat_vec_size FEAT_VEC_SIZE, -feat_vec_size FEAT_VEC_SIZE
#                         If specified, feature embedding sizes will be set to
#                         this. Otherwise, feat_vec_exponent will be used.
#                         (default: -1)
#   --feat_vec_exponent FEAT_VEC_EXPONENT, -feat_vec_exponent FEAT_VEC_EXPONENT
#                         If -feat_merge_size is not set, feature embedding
#                         sizes will be set to N^feat_vec_exponent where N is
#                         the number of values the feature takes. (default: 0.7)
#
# Model- Encoder-Decoder:
#   --model_type {text,img,audio,vec}, -model_type {text,img,audio,vec}
#                         Type of source model to use. Allows the system to
#                         incorporate non-text inputs. Options are
#                         [text|img|audio|vec]. (default: text)
#   --model_dtype {fp32,fp16}, -model_dtype {fp32,fp16}
#                         Data type of the model. (default: fp32)
#   --encoder_type {rnn,brnn,ggnn,mean,transformer,cnn}, -encoder_type {rnn,brnn,ggnn,mean,transformer,cnn}
#                         Type of encoder layer to use. Non-RNN layers are
#                         experimental. Options are
#                         [rnn|brnn|ggnn|mean|transformer|cnn]. (default: rnn)
#   --decoder_type {rnn,transformer,cnn}, -decoder_type {rnn,transformer,cnn}
#                         Type of decoder layer to use. Non-RNN layers are
#                         experimental. Options are [rnn|transformer|cnn].
#                         (default: rnn)
#   --layers LAYERS, -layers LAYERS
#                         Number of layers in enc/dec. (default: -1)
#   --enc_layers ENC_LAYERS, -enc_layers ENC_LAYERS
#                         Number of layers in the encoder (default: 2)
#   --dec_layers DEC_LAYERS, -dec_layers DEC_LAYERS
#                         Number of layers in the decoder (default: 2)
#   --rnn_size RNN_SIZE, -rnn_size RNN_SIZE
#                         Size of rnn hidden states. Overwrites enc_rnn_size and
#                         dec_rnn_size (default: -1)
#   --enc_rnn_size ENC_RNN_SIZE, -enc_rnn_size ENC_RNN_SIZE
#                         Size of encoder rnn hidden states. Must be equal to
#                         dec_rnn_size except for speech-to-text. (default: 500)
#   --dec_rnn_size DEC_RNN_SIZE, -dec_rnn_size DEC_RNN_SIZE
#                         Size of decoder rnn hidden states. Must be equal to
#                         enc_rnn_size except for speech-to-text. (default: 500)
#   --audio_enc_pooling AUDIO_ENC_POOLING, -audio_enc_pooling AUDIO_ENC_POOLING
#                         The amount of pooling of audio encoder, either the
#                         same amount of pooling across all layers indicated by
#                         a single number, or different amounts of pooling per
#                         layer separated by comma. (default: 1)
#   --cnn_kernel_width CNN_KERNEL_WIDTH, -cnn_kernel_width CNN_KERNEL_WIDTH
#                         Size of windows in the cnn, the kernel_size is
#                         (cnn_kernel_width, 1) in conv layer (default: 3)
#   --input_feed INPUT_FEED, -input_feed INPUT_FEED
#                         Feed the context vector at each time step as
#                         additional input (via concatenation with the word
#                         embeddings) to the decoder. (default: 1)
#   --bridge, -bridge     Have an additional layer between the last encoder
#                         state and the first decoder state (default: False)
#   --rnn_type {LSTM,GRU,SRU}, -rnn_type {LSTM,GRU,SRU}
#                         The gate type to use in the RNNs (default: LSTM)
#   --brnn, -brnn         Deprecated, use `encoder_type`. (default: None)
#   --context_gate {source,target,both}, -context_gate {source,target,both}
#                         Type of context gate to use. Do not select for no
#                         context gate. (default: None)
#   --bridge_extra_node BRIDGE_EXTRA_NODE, -bridge_extra_node BRIDGE_EXTRA_NODE
#                         Graph encoder bridges only extra node to decoder as
#                         input (default: True)
#   --bidir_edges BIDIR_EDGES, -bidir_edges BIDIR_EDGES
#                         Graph encoder autogenerates bidirectional edges
#                         (default: True)
#   --state_dim STATE_DIM, -state_dim STATE_DIM
#                         Number of state dimensions in the graph encoder
#                         (default: 512)
#   --n_edge_types N_EDGE_TYPES, -n_edge_types N_EDGE_TYPES
#                         Number of edge types in the graph encoder (default: 2)
#   --n_node N_NODE, -n_node N_NODE
#                         Number of nodes in the graph encoder (default: 2)
#   --n_steps N_STEPS, -n_steps N_STEPS
#                         Number of steps to advance graph encoder (default: 2)
#   --src_vocab SRC_VOCAB, -src_vocab SRC_VOCAB
#                         Path to an existing source vocabulary. Format: one
#                         word per line. (default: )
#
# Model- Attention:
#   --global_attention {dot,general,mlp,none}, -global_attention {dot,general,mlp,none}
#                         The attention type to use: dotprod or general (Luong)
#                         or MLP (Bahdanau) (default: general)
#   --global_attention_function {softmax,sparsemax}, -global_attention_function {softmax,sparsemax}
#   --self_attn_type SELF_ATTN_TYPE, -self_attn_type SELF_ATTN_TYPE
#                         Self attention type in Transformer decoder layer --
#                         currently "scaled-dot" or "average" (default: scaled-
#                         dot)
#   --max_relative_positions MAX_RELATIVE_POSITIONS, -max_relative_positions MAX_RELATIVE_POSITIONS
#                         Maximum distance between inputs in relative positions
#                         representations. For more detailed information, see:
#                         https://arxiv.org/pdf/1803.02155.pdf (default: 0)
#   --heads HEADS, -heads HEADS
#                         Number of heads for transformer self-attention
#                         (default: 8)
#   --transformer_ff TRANSFORMER_FF, -transformer_ff TRANSFORMER_FF
#                         Size of hidden transformer feed-forward (default:
#                         2048)
#   --aan_useffn, -aan_useffn
#                         Turn on the FFN layer in the AAN decoder (default:
#                         False)
#
# Model - Alignement:
#   --lambda_align LAMBDA_ALIGN, -lambda_align LAMBDA_ALIGN
#                         Lambda value for alignement loss of Garg et al
#                         (2019)For more detailed information, see:
#                         https://arxiv.org/abs/1909.02074 (default: 0.0)
#   --alignment_layer ALIGNMENT_LAYER, -alignment_layer ALIGNMENT_LAYER
#                         Layer number which has to be supervised. (default: -3)
#   --alignment_heads ALIGNMENT_HEADS, -alignment_heads ALIGNMENT_HEADS
#                         N. of cross attention heads per layer to supervised
#                         with (default: 0)
#   --full_context_alignment, -full_context_alignment
#                         Whether alignment is conditioned on full target
#                         context. (default: False)
#
# Generator:
#   --copy_attn, -copy_attn
#                         Train copy attention layer. (default: False)
#   --copy_attn_type {dot,general,mlp,none}, -copy_attn_type {dot,general,mlp,none}
#                         The copy attention type to use. Leave as None to use
#                         the same as -global_attention. (default: None)
#   --generator_function {softmax,sparsemax}, -generator_function {softmax,sparsemax}
#                         Which function to use for generating probabilities
#                         over the target vocabulary (choices: softmax,
#                         sparsemax) (default: softmax)
#   --copy_attn_force, -copy_attn_force
#                         When available, train to copy. (default: False)
#   --reuse_copy_attn, -reuse_copy_attn
#                         Reuse standard attention for copy (default: False)
#   --copy_loss_by_seqlength, -copy_loss_by_seqlength
#                         Divide copy loss by length of sequence (default:
#                         False)
#   --coverage_attn, -coverage_attn
#                         Train a coverage attention layer. (default: False)
#   --lambda_coverage LAMBDA_COVERAGE, -lambda_coverage LAMBDA_COVERAGE
#                         Lambda value for coverage loss of See et al (2017)
#                         (default: 0.0)
#   --loss_scale LOSS_SCALE, -loss_scale LOSS_SCALE
#                         For FP16 training, the static loss scale to use. If
#                         not set, the loss scale is dynamically computed.
#                         (default: 0)
#   --apex_opt_level {O0,O1,O2,O3}, -apex_opt_level {O0,O1,O2,O3}
#                         For FP16 training, the opt_level to use.See
#                         https://nvidia.github.io/apex/amp.html#opt-levels.
#                         (default: O1)
#
# General:
#   --data DATA, -data DATA
#                         Path prefix to the ".train.pt" and ".valid.pt" file
#                         path from preprocess.py (default: None)
#   --data_ids DATA_IDS [DATA_IDS ...], -data_ids DATA_IDS [DATA_IDS ...]
#                         In case there are several corpora. (default: [None])
#   --data_weights DATA_WEIGHTS [DATA_WEIGHTS ...], -data_weights DATA_WEIGHTS [DATA_WEIGHTS ...]
#                         Weights of different corpora, should follow the same
#                         order as in -data_ids. (default: [1])
#   --data_to_noise DATA_TO_NOISE [DATA_TO_NOISE ...], -data_to_noise DATA_TO_NOISE [DATA_TO_NOISE ...]
#                         IDs of datasets on which to apply noise. (default: [])
#   --save_model SAVE_MODEL, -save_model SAVE_MODEL
#                         Model filename (the model will be saved as
#                         <save_model>_N.pt where N is the number of steps
#                         (default: model)
#   --save_checkpoint_steps SAVE_CHECKPOINT_STEPS, -save_checkpoint_steps SAVE_CHECKPOINT_STEPS
#                         Save a checkpoint every X steps (default: 5000)
#   --keep_checkpoint KEEP_CHECKPOINT, -keep_checkpoint KEEP_CHECKPOINT
#                         Keep X checkpoints (negative: keep all) (default: -1)
#   --gpuid [GPUID [GPUID ...]], -gpuid [GPUID [GPUID ...]]
#                         Deprecated see world_size and gpu_ranks. (default: [])
#   --gpu_ranks [GPU_RANKS [GPU_RANKS ...]], -gpu_ranks [GPU_RANKS [GPU_RANKS ...]]
#                         list of ranks of each process. (default: [])
#   --world_size WORLD_SIZE, -world_size WORLD_SIZE
#                         total number of distributed processes. (default: 1)
#   --gpu_backend GPU_BACKEND, -gpu_backend GPU_BACKEND
#                         Type of torch distributed backend (default: nccl)
#   --gpu_verbose_level GPU_VERBOSE_LEVEL, -gpu_verbose_level GPU_VERBOSE_LEVEL
#                         Gives more info on each process per GPU. (default: 0)
#   --master_ip MASTER_IP, -master_ip MASTER_IP
#                         IP of master for torch.distributed training. (default:
#                         localhost)
#   --master_port MASTER_PORT, -master_port MASTER_PORT
#                         Port of master for torch.distributed training.
#                         (default: 10000)
#   --queue_size QUEUE_SIZE, -queue_size QUEUE_SIZE
#                         Size of queue for each process in producer/consumer
#                         (default: 40)
#   --seed SEED, -seed SEED
#                         Random seed used for the experiments reproducibility.
#                         (default: -1)
#
# Initialization:
#   --param_init PARAM_INIT, -param_init PARAM_INIT
#                         Parameters are initialized over uniform distribution
#                         with support (-param_init, param_init). Use 0 to not
#                         use initialization (default: 0.1)
#   --param_init_glorot, -param_init_glorot
#                         Init parameters with xavier_uniform. Required for
#                         transformer. (default: False)
#   --train_from TRAIN_FROM, -train_from TRAIN_FROM
#                         If training from a checkpoint then this is the path to
#                         the pretrained model's state_dict. (default: )
#   --reset_optim {none,all,states,keep_states}, -reset_optim {none,all,states,keep_states}
#                         Optimization resetter when train_from. (default: none)
#   --pre_word_vecs_enc PRE_WORD_VECS_ENC, -pre_word_vecs_enc PRE_WORD_VECS_ENC
#                         If a valid path is specified, then this will load
#                         pretrained word embeddings on the encoder side. See
#                         README for specific formatting instructions. (default:
#                         None)
#   --pre_word_vecs_dec PRE_WORD_VECS_DEC, -pre_word_vecs_dec PRE_WORD_VECS_DEC
#                         If a valid path is specified, then this will load
#                         pretrained word embeddings on the decoder side. See
#                         README for specific formatting instructions. (default:
#                         None)
#   --fix_word_vecs_enc, -fix_word_vecs_enc
#                         Fix word embeddings on the encoder side. (default:
#                         False)
#   --fix_word_vecs_dec, -fix_word_vecs_dec
#                         Fix word embeddings on the decoder side. (default:
#                         False)
#
# Optimization- Type:
#   --batch_size BATCH_SIZE, -batch_size BATCH_SIZE
#                         Maximum batch size for training (default: 64)
#   --batch_size_multiple BATCH_SIZE_MULTIPLE, -batch_size_multiple BATCH_SIZE_MULTIPLE
#                         Batch size multiple for token batches. (default: None)
#   --batch_type {sents,tokens}, -batch_type {sents,tokens}
#                         Batch grouping for batch_size. Standard is sents.
#                         Tokens will do dynamic batching (default: sents)
#   --pool_factor POOL_FACTOR, -pool_factor POOL_FACTOR
#                         Factor used in data loading and batch creations. It
#                         will load the equivalent of `pool_factor` batches,
#                         sort them by the according `sort_key` to produce
#                         homogeneous batches and reduce padding, and yield the
#                         produced batches in a shuffled way. Inspired by
#                         torchtext's pool mechanism. (default: 8192)
#   --normalization {sents,tokens}, -normalization {sents,tokens}
#                         Normalization method of the gradient. (default: sents)
#   --accum_count ACCUM_COUNT [ACCUM_COUNT ...], -accum_count ACCUM_COUNT [ACCUM_COUNT ...]
#                         Accumulate gradient this many times. Approximately
#                         equivalent to updating batch_size * accum_count
#                         batches at once. Recommended for Transformer.
#                         (default: [1])
#   --accum_steps ACCUM_STEPS [ACCUM_STEPS ...], -accum_steps ACCUM_STEPS [ACCUM_STEPS ...]
#                         Steps at which accum_count values change (default:
#                         [0])
#   --valid_steps VALID_STEPS, -valid_steps VALID_STEPS
#                         Perfom validation every X steps (default: 10000)
#   --valid_batch_size VALID_BATCH_SIZE, -valid_batch_size VALID_BATCH_SIZE
#                         Maximum batch size for validation (default: 32)
#   --max_generator_batches MAX_GENERATOR_BATCHES, -max_generator_batches MAX_GENERATOR_BATCHES
#                         Maximum batches of words in a sequence to run the
#                         generator on in parallel. Higher is faster, but uses
#                         more memory. Set to 0 to disable. (default: 32)
#   --train_steps TRAIN_STEPS, -train_steps TRAIN_STEPS
#                         Number of training steps (default: 100000)
#   --single_pass, -single_pass
#                         Make a single pass over the training dataset.
#                         (default: False)
#   --epochs EPOCHS, -epochs EPOCHS
#                         Deprecated epochs see train_steps (default: 0)
#   --early_stopping EARLY_STOPPING, -early_stopping EARLY_STOPPING
#                         Number of validation steps without improving.
#                         (default: 0)
#   --early_stopping_criteria [EARLY_STOPPING_CRITERIA [EARLY_STOPPING_CRITERIA ...]], -early_stopping_criteria [EARLY_STOPPING_CRITERIA [EARLY_STOPPING_CRITERIA ...]]
#                         Criteria to use for early stopping. (default: None)
#   --optim {sgd,adagrad,adadelta,adam,sparseadam,adafactor,fusedadam}, -optim {sgd,adagrad,adadelta,adam,sparseadam,adafactor,fusedadam}
#                         Optimization method. (default: sgd)
#   --adagrad_accumulator_init ADAGRAD_ACCUMULATOR_INIT, -adagrad_accumulator_init ADAGRAD_ACCUMULATOR_INIT
#                         Initializes the accumulator values in adagrad. Mirrors
#                         the initial_accumulator_value option in the tensorflow
#                         adagrad (use 0.1 for their default). (default: 0)
#   --max_grad_norm MAX_GRAD_NORM, -max_grad_norm MAX_GRAD_NORM
#                         If the norm of the gradient vector exceeds this,
#                         renormalize it to have the norm equal to max_grad_norm
#                         (default: 5)
#   --dropout DROPOUT [DROPOUT ...], -dropout DROPOUT [DROPOUT ...]
#                         Dropout probability; applied in LSTM stacks. (default:
#                         [0.3])
#   --attention_dropout ATTENTION_DROPOUT [ATTENTION_DROPOUT ...], -attention_dropout ATTENTION_DROPOUT [ATTENTION_DROPOUT ...]
#                         Attention Dropout probability. (default: [0.1])
#   --dropout_steps DROPOUT_STEPS [DROPOUT_STEPS ...], -dropout_steps DROPOUT_STEPS [DROPOUT_STEPS ...]
#                         Steps at which dropout changes. (default: [0])
#   --truncated_decoder TRUNCATED_DECODER, -truncated_decoder TRUNCATED_DECODER
#                         Truncated bptt. (default: 0)
#   --adam_beta1 ADAM_BETA1, -adam_beta1 ADAM_BETA1
#                         The beta1 parameter used by Adam. Almost without
#                         exception a value of 0.9 is used in the literature,
#                         seemingly giving good results, so we would discourage
#                         changing this value from the default without due
#                         consideration. (default: 0.9)
#   --adam_beta2 ADAM_BETA2, -adam_beta2 ADAM_BETA2
#                         The beta2 parameter used by Adam. Typically a value of
#                         0.999 is recommended, as this is the value suggested
#                         by the original paper describing Adam, and is also the
#                         value adopted in other frameworks such as Tensorflow
#                         and Keras, i.e. see: https://www.tensorflow.org/api_do
#                         cs/python/tf/train/AdamOptimizer or
#                         https://keras.io/optimizers/ . Whereas recently the
#                         paper "Attention is All You Need" suggested a value of
#                         0.98 for beta2, this parameter may not work well for
#                         normal models / default baselines. (default: 0.999)
#   --label_smoothing LABEL_SMOOTHING, -label_smoothing LABEL_SMOOTHING
#                         Label smoothing value epsilon. Probabilities of all
#                         non-true labels will be smoothed by epsilon /
#                         (vocab_size - 1). Set to zero to turn off label
#                         smoothing. For more detailed information, see:
#                         https://arxiv.org/abs/1512.00567 (default: 0.0)
#   --average_decay AVERAGE_DECAY, -average_decay AVERAGE_DECAY
#                         Moving average decay. Set to other than 0 (e.g. 1e-4)
#                         to activate. Similar to Marian NMT implementation:
#                         http://www.aclweb.org/anthology/P18-4020 For more
#                         detail on Exponential Moving Average:
#                         https://en.wikipedia.org/wiki/Moving_average (default:
#                         0)
#   --average_every AVERAGE_EVERY, -average_every AVERAGE_EVERY
#                         Step for moving average. Default is every update, if
#                         -average_decay is set. (default: 1)
#   --src_noise {sen_shuffling,infilling,mask} [{sen_shuffling,infilling,mask} ...], -src_noise {sen_shuffling,infilling,mask} [{sen_shuffling,infilling,mask} ...]
#   --src_noise_prob SRC_NOISE_PROB [SRC_NOISE_PROB ...], -src_noise_prob SRC_NOISE_PROB [SRC_NOISE_PROB ...]
#                         Probabilities of src_noise functions (default: [])
#
# Optimization- Rate:
#   --learning_rate LEARNING_RATE, -learning_rate LEARNING_RATE
#                         Starting learning rate. Recommended settings: sgd = 1,
#                         adagrad = 0.1, adadelta = 1, adam = 0.001 (default:
#                         1.0)
#   --learning_rate_decay LEARNING_RATE_DECAY, -learning_rate_decay LEARNING_RATE_DECAY
#                         If update_learning_rate, decay learning rate by this
#                         much if steps have gone past start_decay_steps
#                         (default: 0.5)
#   --start_decay_steps START_DECAY_STEPS, -start_decay_steps START_DECAY_STEPS
#                         Start decaying every decay_steps after
#                         start_decay_steps (default: 50000)
#   --decay_steps DECAY_STEPS, -decay_steps DECAY_STEPS
#                         Decay every decay_steps (default: 10000)
#   --decay_method {noam,noamwd,rsqrt,none}, -decay_method {noam,noamwd,rsqrt,none}
#                         Use a custom decay rate. (default: none)
#   --warmup_steps WARMUP_STEPS, -warmup_steps WARMUP_STEPS
#                         Number of warmup steps for custom decay. (default:
#                         4000)
#
# Logging:
#   --report_every REPORT_EVERY, -report_every REPORT_EVERY
#                         Print stats at this interval. (default: 50)
#   --log_file LOG_FILE, -log_file LOG_FILE
#                         Output logs to a file under this path. (default: )
#   --log_file_level {CRITICAL,ERROR,WARNING,INFO,DEBUG,NOTSET,50,40,30,20,10,0}, -log_file_level {CRITICAL,ERROR,WARNING,INFO,DEBUG,NOTSET,50,40,30,20,10,0}
#   --exp_host EXP_HOST, -exp_host EXP_HOST
#                         Send logs to this crayon server. (default: )
#   --exp EXP, -exp EXP   Name of the experiment for logging. (default: )
#   --tensorboard, -tensorboard
#                         Use tensorboard for visualization during training.
#                         Must have the library tensorboard >= 1.14. (default:
#                         False)
#   --tensorboard_log_dir TENSORBOARD_LOG_DIR, -tensorboard_log_dir TENSORBOARD_LOG_DIR
#                         Log directory for Tensorboard. This is also the name
#                         of the run. (default: runs/onmt)
#
# Speech:
#   --sample_rate SAMPLE_RATE, -sample_rate SAMPLE_RATE
#                         Sample rate. (default: 16000)
#   --window_size WINDOW_SIZE, -window_size WINDOW_SIZE
#                         Window size for spectrogram in seconds. (default:
#                         0.02)
#   --image_channel_size {3,1}, -image_channel_size {3,1}
#                         Using grayscale image can training model faster and
#                         smaller (default: 3)

# %%
# !onmt_train --data data/tanaka --save_model tanaka-model --world_size 1 --gpu_ranks 0 --train_steps 20000
# Out:
# [2021-01-30 08:40:31,070 INFO]  * src vocab size = 6636
# [2021-01-30 08:40:31,071 INFO]  * tgt vocab size = 8778
# [2021-01-30 08:40:31,071 INFO] Building model...
# [2021-01-30 08:40:41,276 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(6636, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(8778, 500, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
#       (linear_in): Linear(in_features=500, out_features=500, bias=False)
#       (linear_out): Linear(in_features=1000, out_features=500, bias=False)
#     )
#   )
#   (generator): Sequential(
#     (0): Linear(in_features=500, out_features=8778, bias=True)
#     (1): Cast()
#     (2): LogSoftmax(dim=-1)
#   )
# )
# [2021-01-30 08:40:41,276 INFO] encoder: 7326000
# [2021-01-30 08:40:41,276 INFO] decoder: 14544778
# [2021-01-30 08:40:41,276 INFO] * number of parameters: 21870778
# [2021-01-30 08:40:41,280 INFO] Starting training on GPU: [0]
# [2021-01-30 08:40:41,280 INFO] Start training loop and validate every 10000 steps...
# [2021-01-30 08:40:41,281 INFO] Loading dataset from data/tanaka.train.0.pt
# [2021-01-30 08
# [2021-01-30 08:58:09,163 INFO] Step 19800/20000; acc:  82.05; ppl:  1.87; xent: 0.62; lr: 1.00000; 9409/15344 tok/s;   1048 sec
# [2021-01-30 08:58:11,821 INFO] Step 19850/20000; acc:  81.84; ppl:  1.88; xent: 0.63; lr: 1.00000; 9641/15372 tok/s;   1051 sec
# [2021-01-30 08:58:14,392 INFO] Step 19900/20000; acc:  82.28; ppl:  1.85; xent: 0.62; lr: 1.00000; 9783/15207 tok/s;   1053 sec
# [2021-01-30 08:58:17,012 INFO] Step 19950/20000; acc:  81.87; ppl:  1.88; xent: 0.63; lr: 1.00000; 9651/15365 tok/s;   1056 sec
# [2021-01-30 08:58:19,617 INFO] Step 20000/20000; acc:  81.84; ppl:  1.87; xent: 0.63; lr: 1.00000; 9898/15141 tok/s;   1058 sec
# [2021-01-30 08:58:19,617 INFO] Loading dataset from data/tanaka.valid.0.pt
# [2021-01-30 08:58:19,624 INFO] number of examples: 500
# [2021-01-30 08:58:19,866 INFO] Validation perplexity: 4.25515
# [2021-01-30 08:58:19,866 INFO] Validation accuracy: 71.9196
# [2021-01-30 08:58:19,912 INFO] Saving checkpoint tanaka-model_step_20000.pt

# %% [markdown]
# ## 翻訳モデル
# 学習されたモデルは tanaka-model_step_20000.pt のような名前で保存されています。

# %%
ls -l
# Out:
# total 343884
# drwxr-xr-x  2 root root     4096 Aug 17 15:26 available_models/
# drwxr-xr-x  4 root root     4096 Jan 30 08:39 build/
# -rw-r--r--  1 root root     7873 Aug 17 15:26 CHANGELOG.md
# drwxr-xr-x  2 root root     4096 Aug 17 15:26 config/
# -rw-r--r--  1 root root     4126 Aug 17 15:26 CONTRIBUTING.md
# drwxr-xr-x  3 root root     4096 Jan 30 08:39 data/
# drwxr-xr-x  2 root root     4096 Jan 30 08:39 dist/
# drwxr-xr-x  3 root root     4096 Aug 17 15:26 docs/
# -rw-r--r--  1 root root       36 Aug 17 15:26 floyd_requirements.txt
# -rw-r--r--  1 root root       30 Aug 17 15:26 floyd.yml
# -rw-r--r--  1 root root     4408 Aug 17 15:26 github_deploy_key_opennmt_opennmt_py.enc
# -rw-r--r--  1 root root     1072 Aug 17 15:26 LICENSE.md
# drwxr-xr-x 11 root root     4096 Aug 17 15:26 onmt/
# drwxr-xr-x  2 root root     4096 Jan 30 08:39 OpenNMT_py.egg-info/
# -rw-r--r--  1 root root       99 Aug 17 15:26 preprocess.py
# -rw-r--r--  1 root root     7867 Aug 17 15:26 README.md
# -rw-r--r--  1 root root      267 Aug 17 15:26 requirements.opt.txt
# -rw-r--r--  1 root root       95 Aug 17 15:26 server.py
# -rw-r--r--  1 root root     1409 Aug 17 15:26 setup.py
# drwxr-xr-x  3 root root     4096 Jan 30 08:39 small_parallel_enja/
# -rw-r--r--  1 root root 88003492 Jan 30 08:49 tanaka-model_step_10000.pt
# -rw-r--r--  1 root root 88003492 Jan 30 08:53 tanaka-model_step_15000.pt
# -rw-r--r--  1 root root 88003492 Jan 30 08:58 tanaka-model_step_20000.pt
# -rw-r--r--  1 root root 88003492 Jan 30 08:45 tanaka-model_step_5000.pt
# drwxr-xr-x  3 root root     4096 Aug 17 15:26 tools/
# -rw-r--r--  1 root root       94 Aug 17 15:26 train.py
# -rw-r--r--  1 root root       98 Aug 17 15:26 translate.py

# %% [markdown]
# ## デコード
# onmt_translate というコマンドでデコードします。一つ前に学習した翻訳モデルのうちの1つを指定します。
# --output pred.txt というので結果を保存するファイルを指定します。
# --replace_unk というのは未知語処理をするというオプションです。
# --verbose は結果を冗長に画面にも表示させるオプションです。

# %%
# !onmt_translate --model tanaka-model_step_20000.pt --src small_parallel_enja/test.en --output pred.txt --replace_unk --verbose
# Out:
# [2021-01-30 08:58:22,099 INFO] Translating shard 0.
# /usr/local/lib/python3.6/dist-packages/OpenNMT_py-1.2.0-py3.6.egg/onmt/translate/beam_search.py:209: UserWarning: An output with one or more elements was resized since it had shape [150], which does not match the required output shape [30, 5].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /pytorch/aten/src/ATen/native/Resize.cpp:19.)
#   torch.mul(self.topk_scores, length_penalty, out=self.topk_log_probs)
# [2021-01-30 08:58:23,099 INFO]
# SENT 1: ['they', 'finally', 'acknowledged', 'it', 'as', 'true', '.']
# PRED 1: 彼 ら は ついに それ を 事実 と し た 。
# PRED SCORE: -1.6511
#
# [2021-01-30 08:58:23,099 INFO]
# SENT 2: ['he', 'didn', "'t", 'care', 'for', 'swimming', '.']
# PRED 2: 彼 は 泳 ぐ 気 が し な かっ た 。
# PRED SCORE: -0.8452
#
# [2021-01-30 08:58:23,099 INFO]
# SENT 3: ['he', 'is', 'no', 'less', 'kind', 'than', 'his', 'sister', '.']
# PRED 3: 彼 は 姉 に 劣 ら ず 頭 が い い 。
# PRED SCORE: -2.9560
#
# [2021-01-30 08:58:23,099 INFO]
# SENT 4: ['you', 'must', 'be', 'back', 'before', 'ten', '.']
# PRED 4: １０ 時 前 に 戻 ら な けれ ば な ら な い 。
# PRED SCORE: -2.2555
#
# [2021-01-30 08:58:23,099 INFO]
# SENT 5: ['break', 'a', 'leg', '.']
# PRED 5: 働 き 過ぎ た 。
# PRED SCORE: -5.6590
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 6: ['she', 'lives', 'next', 'door', 'to', 'us', '.']
# PRED 6: 彼女 は 私 達 の 隣 に 住 ん で い る 。
# PRED SCORE: -0.7922
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 7: ['i', "'m", 'about', 'to', 'tell', 'you', 'the', 'answer', '.']
# PRED 7: お 答え 下さ い 。
# PRED SCORE: -3.3310
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 8: ['i', "'m", 'a', 'person', 'who', 'lives', 'for', 'the', 'moment', '.']
# PRED 8: 私 は 今 の ところ に 住 ん で い る 人 で す 。
# PRED SCORE: -3.3921
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 9: ['we', 'have', 'this', 'game', 'on', 'ice', '.']
# PRED 9: この 試合 は 間違い だ 。
# PRED SCORE: -3.1050
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 10: ['will', 'you', 'give', 'me', 'your', 'reasons', 'for', 'doing', 'this', '?']
# PRED 10: この 説明 を し て くれ ま せ ん か 。
# PRED SCORE: -3.5651
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 11: ['she', 'likes', 'the', 'teacher', '.']
# PRED 11: 彼女 は 先生 が 好き で す 。
# PRED SCORE: -0.9955
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 12: ['it', "'s", 'business', '.']
# PRED 12: 商売 は 商売 で す 。
# PRED SCORE: -2.9806
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 13: ['these', 'shoes', 'will', 'last', 'you', 'two', 'years', '.']
# PRED 13: この 靴 は あなた に 二 年間 あ る だ ろ う 。
# PRED SCORE: -5.2539
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 14: ['he', 'made', 'his', 'son', 'attend', 'the', 'meeting', 'in', 'his', 'place', '.']
# PRED 14: 彼 は 息子 に 会 で その 会合 に 出席 し た 。
# PRED SCORE: -4.1697
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 15: ['give', 'your', 'argument', 'against', 'going', '.']
# PRED 15: あなた の 仲間 に 行 く よう に し なさ い 。
# PRED SCORE: -5.2910
#
# [2021-01-30 08:58:23,100 INFO]
# SENT 16: ['at', 'the', 'end', 'of', 'a', 'working', 'day', 'everybody', 'is', 'in', 'a', 'hurry', 'to', 'get', 'home', '.']
# PRED 16: 仕事 の 終わり に 働 く 。
# PRED SCORE: -6.1054
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 17: ['i', 'was', 'unable', 'to', 'look', 'her', 'in', 'the', 'face', '.']
# PRED 17: 私 は 彼女 の 顔 を まとも に 見 る こと が でき な かっ た 。
# PRED SCORE: -1.8413
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 18: ['some', 'people', 'go', 'to', 'church', 'on', 'sunday', 'morning', '.']
# PRED 18: 日曜 の 朝教会 に は 誰 も い る 。
# PRED SCORE: -5.0025
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 19: ['i', 'must', 'put', 'my', 'watch', 'forward', 'two', 'minutes', '.']
# PRED 19: 時計 を ２ 分 後 に 出 し ま す 。
# PRED SCORE: -2.6360
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 20: ['that', 'is', 'the', 'boy', 'i', 'saw', 'yesterday', '.']
# PRED 20: あれ が 昨日 私 が 会 っ た 少年 で す 。
# PRED SCORE: -2.6435
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 21: ['ten', 'years', 'is', 'a', 'long', 'time', 'to', 'wait', '.']
# PRED 21: １０ 年 と は 待 つ の は 長 い 時間 だ 。
# PRED SCORE: -3.6069
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 22: ['i', 'met', 'him', 'in', 'tokyo', 'by', 'chance', '.']
# PRED 22: 私 は 偶然 彼 に 東京 で 会 っ た 。
# PRED SCORE: -1.6776
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 23: ['i', 'often', 'go', 'swimming', 'in', 'the', 'river', '.']
# PRED 23: 私 は よく 川 で 泳ぎ に 行 き ま す 。
# PRED SCORE: -2.5411
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 24: ['he', 'called', 'out', 'for', 'help', '.']
# PRED 24: 彼 は 大声 で 助け を 求め た 。
# PRED SCORE: -0.6005
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 25: ['he', 'rescued', 'the', 'child', 'from', 'the', 'fire', '.']
# PRED 25: 彼 は その 子 を 火 から 救 っ た 。
# PRED SCORE: -1.0887
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 26: ['i', 'cannot', 'agree', 'to', 'his', 'proposal', '.']
# PRED 26: 私 は 彼 の 提案 に 同意 でき な い 。
# PRED SCORE: -0.6827
#
# [2021-01-30 08:58:23,101 INFO]
# SENT 27: ['we', 'read', 'the', 'letter', 'again', 'and', 'again', '.']
# PRED 27: 私 たち は 何 度 も その 手紙 を 読 ん だ 。
# PRED SCORE: -1.7523
#
# [2021-01-30 08:58:23,102 INFO]
# SENT 28: ['i', "'m", 'happy', 'to', 'see', 'you', '.']
# PRED 28: 私 は あなた に 会え て うれし い 。
# PRED SCORE: -3.5280
#
# [2021-01-30 08:58:23,102 INFO]
# SENT 29: ['ask', 'your', 'dad', 'to', 'help', 'you', '.']
# PRED 29: お 父 さん に お 手伝い くださ い 。
# PRED SCORE: -2.2652
#
# [2021-01-30 08:58:23,102 INFO]
# SENT 30: ['they', 'adopted', 'the', 'proposal', '.']
# PRED 30: 彼 ら は その その 提案 を 断念 し た 。
# PRED SCORE: -1.3578
#
# [2021-01-30 08:58:23,945 INFO]
# SENT 31: ['i', 'feel', 'good', 'in', 'a', 'special', 'way', '.']
# PRED 31: 私 は 特別 な こと が い い 。
# PRED SCORE: -3.4421
#
# [2021-01-30 08:58:23,945 INFO]
# SENT 32: ['nobody', 'has', 'seen', 'him', 'ever', 'since', '.']
# PRED 32: それ 以来 彼 に は 誰 も 見 な かっ た 。
# PRED SCORE: -3.9914
#
# [2021-01-30 08:58:23,945 INFO]
# SENT 33: ['she', 'has', 'seen', 'better', 'days', '.']
# PRED 33: 彼女 は 昔 、 羽振り が よ かっ た 。
# PRED SCORE: -2.7685
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 34: ['please', 'pass', 'it', 'to', 'the', 'other', 'boys', '.']
# PRED 34: それ を ほか の 少年 たち に 回 し て 下さ い 。
# PRED SCORE: -4.9289
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 35: ['i', 'still', 'bear', 'his', 'name', 'in', 'mind', '.']
# PRED 35: 私 は 彼 の 名前 を 心 に 銘記 し て い る 。
# PRED SCORE: -2.4584
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 36: ['i', 'want', 'to', 'marry', 'you', '.']
# PRED 36: 私 は あなた と 結婚 し た い 。
# PRED SCORE: -0.5903
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 37: ['we', 'see', 'them', 'on', 'occasion', '.']
# PRED 37: 今 すぐ 彼 ら を 見かけ る だ ろ う 。
# PRED SCORE: -5.5764
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 38: ['the', 'earth', 'rotates', '.']
# PRED 38: 地球 は 強 く な っ た 。
# PRED SCORE: -2.1466
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 39: ['tell', 'me', 'which', 'you', 'want', '.']
# PRED 39: どちら が 欲し い か 私 に 教え て 下さ い 。
# PRED SCORE: -3.2271
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 40: ['i', 'wish', 'i', 'knew', 'where', 'he', 'was', '!']
# PRED 40: 彼 が どこ に い たら よ かっ た か なあ 。
# PRED SCORE: -2.9745
#
# [2021-01-30 08:58:23,946 INFO]
# SENT 41: ['we', 'took', 'an', 'examination', 'in', 'math', 'last', 'week', '.']
# PRED 41: 私 達 は 先週 数学 の 試験 を 受け た 。
# PRED SCORE: -0.9319
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 42: ['check', ',', 'please', '.']
# PRED 42: 勘定 書 を 頼 む よ 。
# PRED SCORE: -1.4076
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 43: ['i', 'listened', ',', 'but', 'i', 'heard', 'nothing', '.']
# PRED 43: 私 は 聞 い て 何 も 聞 い た 。
# PRED SCORE: -3.9532
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 44: ['she', 'did', 'not', 'marry', 'the', 'man', '.']
# PRED 44: 彼女 は その 男 と 結婚 し な かっ た 。
# PRED SCORE: -0.1139
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 45: ['he', 'doesn', "'t", 'read', 'many', 'books', '.']
# PRED 45: 彼 は あまり 本 を 読 ん で い な い 。
# PRED SCORE: -0.9293
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 46: ['she', 'doesn', "'t", 'have', 'any', 'enemies', '.']
# PRED 46: 彼女 に は 悪意 が な い 。
# PRED SCORE: -1.9834
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 47: ['in', 'the', 'summer', ',', 'it', "'s", 'very', 'humid', '.']
# PRED 47: その 夏 は 非常 に 単調 だ 。
# PRED SCORE: -5.1372
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 48: ['he', 'made', 'me', 'write', 'the', 'letter', 'with', 'a', 'pen', '.']
# PRED 48: 彼 は 私 に その 手紙 を ペン で 書 か せ た 。
# PRED SCORE: -2.5104
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 49: ['he', 'got', 'tired', 'of', 'reading', '.']
# PRED 49: 彼 は 読書 に 飽き た 。
# PRED SCORE: -1.7578
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 50: ['put', 'down', 'your', 'name', 'and', 'address', 'here', '.']
# PRED 50: ここ に お 名前 と お 名前 を お 書 き くださ い 。
# PRED SCORE: -2.8344
#
# [2021-01-30 08:58:23,947 INFO]
# SENT 51: ['she', 'played', 'the', 'piano', 'well', 'enough', '.']
# PRED 51: 彼女 は 上手 に ピアノ を 弾 い た 。
# PRED SCORE: -1.6180
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 52: ['i', "'m", 'still', 'waiting', 'for', 'my', 'order', '.']
# PRED 52: 私 は まだ 注文 し ま し た 。
# PRED SCORE: -1.3889
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 53: ['there', 'are', 'a', 'great', 'many', 'books', 'in', 'this', 'library', '.']
# PRED 53: この 図書 館 に は 非常 に たくさん の 本 が あ る 。
# PRED SCORE: -1.4604
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 54: ['you', 'should', 'avail', 'yourself', 'of', 'every', 'opportunity', '.']
# PRED 54: あらゆる 機会 を 利用 す べ き だ 。
# PRED SCORE: -0.6664
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 55: ['how', 'many', 'schools', 'are', 'there', 'in', 'your', 'city', '?']
# PRED 55: あなた の 街 に は 何 枚 の 脚 が あ り ま す か 。
# PRED SCORE: -3.4695
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 56: ['i', 'don', "'t", 'like', 'sad', 'movies', '.']
# PRED 56: 私 は 映画 が 好き で は な い 。
# PRED SCORE: -1.6066
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 57: ['she', 'was', 'very', 'angry', 'with', 'me', 'when', 'i', 'forgot', 'the', 'appointment', '.']
# PRED 57: 彼女 は 私 が 約束 を 忘れ た 時 に とても 怒 っ た 。
# PRED SCORE: -3.8257
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 58: ['people', 'of', 'your', 'age', 'often', 'have', 'this', 'problem', '.']
# PRED 58: 君 の 年 の 人々 は しばしば この 問題 を 解 く 。
# PRED SCORE: -6.0686
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 59: ['i', 'like', 'your', 'car', '.']
# PRED 59: 私 は 君 の 車 が 好き で す 。
# PRED SCORE: -1.0409
#
# [2021-01-30 08:58:23,948 INFO]
# SENT 60: ['she', 'stood', 'looking', 'at', 'a', 'boat', 'on', 'the', 'river', '.']
# PRED 60: 彼女 は 川 の 中 で ボート を 見 て い た 。
# PRED SCORE: -2.3729
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 61: ['whether', 'he', 'comes', 'or', 'not', ',', 'i', "'ll", 'go', '.']
# PRED 61: 彼 が 来る か どう か は 私 が 行 き ま す 。
# PRED SCORE: -2.7261
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 62: ['i', 'don', "'t", 'get', 'up', 'as', 'early', 'as', 'my', 'mother', '.']
# PRED 62: 私 は 母 ほど 早 く 起き な い 。
# PRED SCORE: -2.3064
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 63: ['any', 'flower', 'will', 'do', ',', 'so', 'long', 'as', 'it', 'is', 'red', '.']
# PRED 63: で さえ 赤 い 。
# PRED SCORE: -3.9894
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 64: ['don', "'t", 'forget', 'to', 'add', 'me', 'in', '.']
# PRED 64: 忘れ ず に 私 を 入れ て くれ 。
# PRED SCORE: -2.0536
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 65: ['you', 'are', 'the', 'only', 'one', '.']
# PRED 65: きみ だけ で す 。
# PRED SCORE: -2.8513
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 66: ['i', 'stick', 'to', 'the', 'point', '.']
# PRED 66: 私 は その 点 に 反対 し て い る 。
# PRED SCORE: -4.4676
#
# [2021-01-30 08:58:24,789 INFO]
# SENT 67: ['i', "'ll", 'be', 'here', 'by', 'monday', '.']
# PRED 67: 私 は 月曜 日 まで に ここ に い ま す 。
# PRED SCORE: -2.3839
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 68: ['she', 'is', 'the', 'happiest', 'in', 'her', 'class', '.']
# PRED 68: 彼女 は クラス で 一番 幸せ だ 。
# PRED SCORE: -2.1859
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 69: ['how', 'beautiful', 'the', 'rising', 'sun', 'is', '!']
# PRED 69: なんて すばらし い 結果 な の だ ろ う 。
# PRED SCORE: -3.4992
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 70: ['nothing', 'is', 'so', 'precious', 'as', 'time', '.']
# PRED 70: 時間 ほど 大切 な もの は な い 。
# PRED SCORE: -0.5965
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 71: ['you', 'did', 'not', 'need', 'to', 'come', 'so', 'early', '.']
# PRED 71: あなた は そんな に 早 く くる 必要 は な かっ た の で す 。
# PRED SCORE: -3.3475
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 72: ['i', 'had', 'some', 'questions', 'and', 'raised', 'my', 'hand', '.']
# PRED 72: 私 は いく つ か 質問 が あ っ た 。
# PRED SCORE: -3.0780
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 73: ['she', 'expressed', 'satisfaction', 'with', 'her', 'life', '.']
# PRED 73: 彼女 は 自分 の 人生 に 満足 し て い る と 言 っ た 。
# PRED SCORE: -1.0250
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 74: ['it', 'was', 'around', 'eight', 'last', 'night', 'when', 'the', 'meeting', 'broke', 'up', '.']
# PRED 74: 昨夜 会 っ た 時 は 、 夜 は ８ 時 だっ た 。
# PRED SCORE: -5.8075
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 75: ['the', 'life', 'of', 'a', 'person', 'is', 'a', 'transient', 'thing', '.']
# PRED 75: 人 の 人生 は 液体 で あ る 。
# PRED SCORE: -5.0335
#
# [2021-01-30 08:58:24,790 INFO]
# SENT 76: ['don', "'t", 'raise', 'my', 'hopes', 'like', 'that', '.']
# PRED 76: そんな よう な もの を 要求 する な 。
# PRED SCORE: -5.1835
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 77: ['they', 'won', 'by', 'force', 'of', 'numbers', '.']
# PRED 77: 彼 ら は 独創 的 に とても でき る 。
# PRED SCORE: -7.0775
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 78: ['i', 'was', 'eating', 'dinner', 'then', '.']
# PRED 78: 私 は 夕食 を 食べ ま し た 。
# PRED SCORE: -2.2158
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 79: ['it', "'s", 'hot', 'today', '.']
# PRED 79: 今日 は 暑 い 。
# PRED SCORE: -0.5883
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 80: ['he', 'is', 'a', 'detective', '.']
# PRED 80: 彼 は サイコ だ 。
# PRED SCORE: -1.9751
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 81: ['he', 'always', 'takes', 'sides', 'with', 'her', '.']
# PRED 81: 彼 は いつ も 彼女 の 味方 を する 。
# PRED SCORE: -0.8273
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 82: ['jane', 'always', 'made', 'out', 'that', 'she', 'was', 'very', 'rich', '.']
# PRED 82: ジェーン は 、 いつ も とても 金持ち だっ た 。
# PRED SCORE: -3.3939
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 83: ['what', 'a', 'bad', 'boy', 'he', 'is', '!']
# PRED 83: 彼 は 何 と 悪 い 子 な の だ ろ う 。
# PRED SCORE: -0.4423
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 84: ['he', 'is', 'what', 'we', 'call', 'the', 'man', 'of', 'the', 'hour', '.']
# PRED 84: 彼 は 私 たち が いつ で も その 男 を 呼 ん で い る 。
# PRED SCORE: -4.9134
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 85: ['in', 'fact', ',', 'he', 'is', 'a', 'nice', 'fellow', '.']
# PRED 85: 実際 は 彼 は い い やつ だ 。
# PRED SCORE: -1.8107
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 86: ['where', 'does', 'the', 'answer', 'lie', '?']
# PRED 86: その 答え は どこ に あ る の で す か 。
# PRED SCORE: -2.5495
#
# [2021-01-30 08:58:24,791 INFO]
# SENT 87: ['you', 'may', 'as', 'well', 'prepare', 'for', 'your', 'examination', '.']
# PRED 87: 試験 の 準備 を し た ほう が い い で す よ 。
# PRED SCORE: -4.0657
#
# [2021-01-30 08:58:24,792 INFO]
# SENT 88: ['i', 'can', "'t", 'see', 'well', '.']
# PRED 88: 物 が よく 見え ま せ ん 。
# PRED SCORE: -0.8089
#
# [2021-01-30 08:58:24,792 INFO]
# SENT 89: ['can', 'we', 'rent', 'a', 'car', '?']
# PRED 89: 車 を 借り られ ま す か 。
# PRED SCORE: -1.0905
#
# [2021-01-30 08:58:24,792 INFO]
# SENT 90: ['a', 'wise', 'man', 'would', 'not', 'say', 'such', 'a', 'thing', '.']
# PRED 90: 賢 い 人 なら 、 その よう な 人 で は な い だ ろ う 。
# PRED SCORE: -6.2419
#
# [2021-01-30 08:58:25,694 INFO]
# SENT 91: ['he', 'told', 'me', 'that', 'she', 'was', 'sick', '.']
# PRED 91: 彼 は 私 に 病気 だ と 言 っ た 。
# PRED SCORE: -1.8112
#
# [2021-01-30 08:58:25,694 INFO]
# SENT 92: ['there', 'was', 'nobody', 'in', 'the', 'garden', '.']
# PRED 92: 庭 に は 誰 も い な かっ た 。
# PRED SCORE: -0.2540
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 93: ['our', 'college', 'is', 'far', 'from', 'the', 'station', '.']
# PRED 93: 私 達 の 大学 は 駅 から 遠 い 。
# PRED SCORE: -1.2419
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 94: ['he', 'had', 'been', 'writing', 'a', 'letter', '.']
# PRED 94: 彼 は 手紙 を 書 き 続け て い た 。
# PRED SCORE: -0.9818
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 95: ['he', 'spoke', 'to', 'her', 'about', 'the', 'matter', '.']
# PRED 95: 彼 は その こと に つ い て 彼女 に 話 し た 。
# PRED SCORE: -0.6862
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 96: ['let', 'me', 'see', 'it', '.']
# PRED 96: 私 に それ を 見せ て 下さ い 。
# PRED SCORE: -1.5343
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 97: ['he', 'sat', 'there', 'with', 'his', 'eyes', 'closed', '.']
# PRED 97: 彼 は 目 を 閉じ て そこ に 座 っ た 。
# PRED SCORE: -0.6847
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 98: ['you', 'should', 'work', 'hard', 'while', 'you', 'are', 'young', '.']
# PRED 98: 若 い 頃 は 一生 懸命 働 く べ き で す 。
# PRED SCORE: -2.4487
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 99: ['he', 'made', 'an', 'abrupt', 'departure', '.']
# PRED 99: 彼 は ぶっきらぼう な 出発 を し た 。
# PRED SCORE: -0.9896
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 100: ['this', 'is', 'how', 'the', 'accident', 'happened', '.']
# PRED 100: この よう に し て 事故 が 起こ っ た の で す 。
# PRED SCORE: -2.0587
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 101: ['jane', 'was', 'a', 'stewardess', 'when', 'she', 'was', 'young', '.']
# PRED 101: ジェーン は 若 い と い う 時 の スチュワーデス だっ た 。
# PRED SCORE: -7.4460
#
# [2021-01-30 08:58:25,695 INFO]
# SENT 102: ['he', 'was', 'afraid', 'of', 'his', 'wife', '.']
# PRED 102: 彼 は 妻 を こわ が っ た 。
# PRED SCORE: -1.6655
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 103: ['how', 'far', 'is', 'it', 'to', 'the', 'station', '?']
# PRED 103: 駅 まで どの くらい あ り ま す か 。
# PRED SCORE: -1.5754
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 104: ['he', 'is', 'as', 'diligent', 'a', 'man', 'as', 'ever', 'lived', '.']
# PRED 104: 彼 は この 上 な く 貧乏 な 男 だ 。
# PRED SCORE: -5.1711
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 105: ['you', 'should', 'not', 'break', 'your', 'promise', '.']
# PRED 105: 約束 を 破 る べ き で は な い 。
# PRED SCORE: -1.1641
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 106: ['we', 'want', 'a', 'house', 'of', 'our', 'own', '.']
# PRED 106: 私 たち は 自分 の 家 を 持 っ て い る 。
# PRED SCORE: -3.3646
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 107: ['you', 'ask', 'me', 'to', 'do', 'the', 'impossible', '.']
# PRED 107: あなた は 私 に 不 可能 な こと を する よう に 頼 ん で 下さ い 。
# PRED SCORE: -7.3571
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 108: ['this', 'baggage', 'three', 'times', 'as', 'heavy', 'as', 'that', 'one', '.']
# PRED 108: この 荷物 は あの 手 の ３ 倍 重 く な っ た 。
# PRED SCORE: -5.1452
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 109: ['i', 'sometimes', 'look', 'back', 'on', 'the', 'good', 'days', 'i', 'had', 'in', 'london', '.']
# PRED 109: ロンドン に い た 良 い 日 に 戻 り ま す 。
# PRED SCORE: -5.7229
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 110: ['i', 'got', 'out', 'of', 'the', 'taxi', '.']
# PRED 110: 私 は タクシー から 降り た 。
# PRED SCORE: -0.7067
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 111: ['i', 'am', 'due', 'to', 'speak', 'tonight', '.']
# PRED 111: 今晩 は 話 す 予定 で す 。
# PRED SCORE: -3.3461
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 112: ['the', 'girls', 'are', 'as', 'busy', 'as', 'bees', '.']
# PRED 112: その 少女 たち は 吉雄 と し て 忙し い 。
# PRED SCORE: -3.7186
#
# [2021-01-30 08:58:25,696 INFO]
# SENT 113: ['there', 'are', 'more', 'girls', 'than', 'boys', 'in', 'our', 'school', '.']
# PRED 113: 学校 に は 少年 より ほか に たくさん の 女の子 が い る 。
# PRED SCORE: -7.3287
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 114: ['the', 'days', 'are', 'getting', 'longer', 'and', 'longer', '.']
# PRED 114: 日 は 長 く 長 く な っ て き ま す 。
# PRED SCORE: -2.2630
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 115: ['lay', 'it', 'on', 'the', 'table', '.']
# PRED 115: テーブル の 上 に 置 い て お き なさ い 。
# PRED SCORE: -1.8802
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 116: ['what', 'are', 'you', 'going', 'to', 'do', 'today', '?']
# PRED 116: あなた は 今日 何 を する つもり で す か 。
# PRED SCORE: -1.8937
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 117: ['it', 'rained', 'hard', 'last', 'night', '.']
# PRED 117: 昨夜 は 強 く 雨 が 降 っ た 。
# PRED SCORE: -2.1847
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 118: ['how', 'about', 'going', 'to', 'the', 'movies', 'tonight', '?']
# PRED 118: 今晩 映画 に 行 く の は どう で す か 。
# PRED SCORE: -2.6772
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 119: ['you', 'have', 'no', 'obligation', 'to', 'help', 'us', '.']
# PRED 119: あなた に は 援助 する 権利 は な い 。
# PRED SCORE: -3.1490
#
# [2021-01-30 08:58:25,697 INFO]
# SENT 120: ['of', 'course', ',', 'i', 'will', 'go', 'there', 'with', 'you', '.']
# PRED 120: もちろん 私 が そこ へ 行 き ま す 。
# PRED SCORE: -1.7923
#
# [2021-01-30 08:58:26,532 INFO]
# SENT 121: ['they', 'slept', 'a', 'little', 'in', 'the', 'room', '.']
# PRED 121: 彼 ら は 部屋 の 中 で 少し 眠 っ た 。
# PRED SCORE: -2.5884
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 122: ['speak', 'your', 'mind', '.']
# PRED 122: 考え を 話 し なさ い 。
# PRED SCORE: -1.4694
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 123: ['the', 'old', 'man', 'died', 'last', 'week', '.']
# PRED 123: その 老人 は 先週 死 ん だ 。
# PRED SCORE: -0.0934
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 124: ['i', 'was', 'astonished', 'to', 'hear', 'what', 'had', 'happened', '.']
# PRED 124: 何 が 起こ っ た 聞 い て びっくり し た 。
# PRED SCORE: -2.5119
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 125: ['his', 'hands', 'had', 'turned', 'blue', 'because', 'of', 'the', 'cold', '.']
# PRED 125: 彼 の 手 は 寒 さ の ため に 青 く な っ た 。
# PRED SCORE: -1.1001
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 126: ['i', 'couldn', "'t", 'make', 'her', 'out', 'at', 'all', '.']
# PRED 126: 私 は 彼女 を 少し も 理解 でき な かっ た 。
# PRED SCORE: -2.7341
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 127: ['it', 'is', 'outside', 'my', 'area', 'of', 'study', '.']
# PRED 127: 私 の 勉強 は 許 さ れ て い る 。
# PRED SCORE: -3.6681
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 128: ['it', 'was', 'careless', 'of', 'you', 'to', 'forget', 'your', 'homework', '.']
# PRED 128: 宿題 を 忘れ た の は 君 が 不 注意 だっ た ね 。
# PRED SCORE: -1.4848
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 129: ['there', 'is', 'a', 'park', 'in', 'front', 'of', 'my', 'house', '.']
# PRED 129: 私 の 家 の 前 に 公園 が あ る 。
# PRED SCORE: -0.4455
#
# [2021-01-30 08:58:26,533 INFO]
# SENT 130: ['i', "'m", 'not', 'tired', 'at', 'all', '.']
# PRED 130: 私 は まったく 疲れ て い な い 。
# PRED SCORE: -2.1250
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 131: ['it', 'makes', 'no', 'difference', 'who', 'i', 'meet', '.']
# PRED 131: 私 が 会 う と は 彼 は 思 わ な い 。
# PRED SCORE: -5.3878
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 132: ['jane', 'is', 'no', 'less', 'beautiful', 'than', 'her', 'mother', '.']
# PRED 132: ジェーン は 母 と まったく 同じ よう に 美人 だ 。
# PRED SCORE: -2.0183
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 133: ['what', 'on', 'earth', 'is', 'the', 'matter', '?']
# PRED 133: 一体 どう し た ん だ 。
# PRED SCORE: -2.1042
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 134: ['i', "'d", 'like', 'to', 'go', 'skiing', 'with', 'her', '.']
# PRED 134: と 彼女 と スキー に 行 き た い 。
# PRED SCORE: -2.3559
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 135: ['the', 'mystery', 'story', 'is', 'so', 'hard', 'that', 'i', 'don', "'t", 'like', 'it', '.']
# PRED 135: 暴動 は とても 難し く て 私 に は 嫌い だ 。
# PRED SCORE: -5.2350
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 136: ['her', 'teacher', 'praised', 'her', '.']
# PRED 136: 彼女 の 先生 は けんか を する 。
# PRED SCORE: -1.8609
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 137: ['here', 'is', 'a', 'letter', 'for', 'you', '.']
# PRED 137: ここ に 君 宛 の 手紙 が あ る 。
# PRED SCORE: -1.0403
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 138: ['the', 'meaning', 'of', 'the', 'words', 'is', 'intelligible', '.']
# PRED 138: 言葉 の 意味 が 燃え て い る 。
# PRED SCORE: -1.9193
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 139: ['speaking', 'of', 'sports', ',', 'can', 'you', 'play', 'tennis', '?']
# PRED 139: スポーツ を し て も い い で す か 。
# PRED SCORE: -3.9332
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 140: ['it', "'s", 'already', 'cleared', 'up', '.']
# PRED 140: もう すっかり 終わ っ た 。
# PRED SCORE: -2.9595
#
# [2021-01-30 08:58:26,534 INFO]
# SENT 141: ['i', 'get', 'up', 'at', 'six', 'every', 'morning', '.']
# PRED 141: 私 は 毎朝 六 時 に 起き ま す 。
# PRED SCORE: -0.4792
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 142: ['the', 'bank', 'was', 'held', 'up', 'last', 'night', '.']
# PRED 142: その 銀行 は 昨晩 、 その 銀行 に 上が っ た 。
# PRED SCORE: -5.5531
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 143: ['i', 'want', 'to', 'marry', 'a', 'girl', 'like', 'her', '.']
# PRED 143: 私 は 彼女 と 結婚 し た い と 結婚 し た い 。
# PRED SCORE: -1.5924
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 144: ['he', 'told', 'us', 'to', 'keep', 'quiet', '.']
# PRED 144: 彼 は 私 たち に 静か に する よう に 言 っ た 。
# PRED SCORE: -0.8293
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 145: ['he', 'is', 'as', 'great', 'a', 'statesman', 'as', 'ever', 'lived', '.']
# PRED 145: 彼 は 偉大 な 政治 家 だ 。
# PRED SCORE: -2.5892
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 146: ['are', 'you', 'proud', 'of', 'your', 'father', '?']
# PRED 146: あなた は お 父 さん を 誇り に 思 い ま す か 。
# PRED SCORE: -1.2331
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 147: ['computers', 'can', 'do', 'the', 'job', 'with', 'ease', '.']
# PRED 147: コンピューター は 簡単 に その 仕事 を でき る 。
# PRED SCORE: -0.9698
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 148: ['this', 'case', 'has', 'an', 'affinity', 'with', 'that', 'one', '.']
# PRED 148: この 件 は あの 件 と あ っ て い る 。
# PRED SCORE: -5.1248
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 149: ['there', "'s", 'an', 'old', 'cherry', 'tree', 'in', 'the', 'garden', '.']
# PRED 149: 庭 に は 古 い 木 が あ る 。
# PRED SCORE: -0.8519
#
# [2021-01-30 08:58:26,535 INFO]
# SENT 150: ['i', 'do', 'not', 'like', 'cats', 'and', 'my', 'brother', 'does', 'not', 'either', '.']
# PRED 150: 猫 も 好き で は あ り ま せ ん 。
# PRED SCORE: -2.3108
#
# [2021-01-30 08:58:27,353 INFO]
# SENT 151: ['my', 'brother', 'has', 'no', 'occupation', 'now', '.']
# PRED 151: 私 の 兄 は 今 宗教 を し ま せ ん 。
# PRED SCORE: -4.8824
#
# [2021-01-30 08:58:27,353 INFO]
# SENT 152: ['he', 'did', 'not', 'so', 'much', 'as', 'turn', 'his', 'head', '.']
# PRED 152: 彼 は 頭 を 下げ さえ し な かっ た 。
# PRED SCORE: -2.0397
#
# [2021-01-30 08:58:27,353 INFO]
# SENT 153: ['he', 'got', 'off', 'at', 'the', 'next', 'bus', 'stop', '.']
# PRED 153: 彼 は 次 の バス 停 で 降り た 。
# PRED SCORE: -1.1237
#
# [2021-01-30 08:58:27,353 INFO]
# SENT 154: ['there', 'is', 'no', 'telling', 'who', 'did', 'this', '.']
# PRED 154: これ を し た か 誰 も わか ら な い 。
# PRED SCORE: -3.4783
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 155: ['she', 'showed', 'me', 'her', 'room', '.']
# PRED 155: 彼女 は 私 に 自分 の 部屋 を 見せ た 。
# PRED SCORE: -1.3431
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 156: ['he', 'asked', 'me', 'which', 'way', 'to', 'go', '.']
# PRED 156: 彼 は 私 に どちら の 道 を 行 け ば よ い か 尋ね た 。
# PRED SCORE: -3.0134
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 157: ['she', 'is', 'anxious', 'to', 'know', 'the', 'results', '.']
# PRED 157: 彼女 は しきり に 結果 を 知 り たが っ て い る 。
# PRED SCORE: -1.4518
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 158: ['there', 'are', 'all', 'kinds', 'of', 'flowers', 'in', 'that', 'garden', '.']
# PRED 158: あの 庭 に は 何 の 花 も あ る 。
# PRED SCORE: -3.0286
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 159: ['he', 'had', 'a', 'blue', 'jacket', 'on', '.']
# PRED 159: 彼 は 青 い 上着 を 着 て い た 。
# PRED SCORE: -0.8982
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 160: ['no', 'one', 'is', 'coming', '.']
# PRED 160: だれ ひとり が 来る 。
# PRED SCORE: -3.6021
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 161: ['he', 'has', 'a', 'warm', 'heart', '.']
# PRED 161: 彼 は 暖か い 。
# PRED SCORE: -0.6626
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 162: ['she', 'recollected', 'the', 'first', 'day', 'when', 'she', 'went', 'to', 'school', '.']
# PRED 162: 彼女 は 学校 へ 行 く 日 に 言い切 っ た 。
# PRED SCORE: -6.1539
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 163: ['please', 'take', 'more', 'care', 'in', 'the', 'future', '.']
# PRED 163: 将来 もっと 注意 し て 下さ い 。
# PRED SCORE: -3.6331
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 164: ['i', 'had', 'a', 'lot', 'of', 'difficulty', 'getting', 'in', 'touch', 'with', 'her', '.']
# PRED 164: 私 は 彼女 と 連絡 を 取 る の が 大変 だっ た 。
# PRED SCORE: -4.6435
#
# [2021-01-30 08:58:27,354 INFO]
# SENT 165: ['the', 'policeman', "'s", 'quick', 'arrival', 'surprised', 'us', '.']
# PRED 165: その 警官 の 速 い 結果 は 私 たち に 驚 い た 。
# PRED SCORE: -5.5556
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 166: ['get', 'in', 'touch', 'with', 'me', 'as', 'soon', 'as', 'you', 'arrive', 'here', '.']
# PRED 166: ここ に 着 い たら すぐ に 連絡 し なさ い 。
# PRED SCORE: -3.2255
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 167: ['it', 'is', 'fact', 'that', 'he', 'ran', 'away', 'from', 'home', '.']
# PRED 167: 彼 が 家出 を し た の は 事実 だ 。
# PRED SCORE: -1.1473
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 168: ['the', 'news', 'made', 'her', 'very', 'sad', '.']
# PRED 168: その ニュース は 彼女 が とても 悲し く な っ た 。
# PRED SCORE: -2.4061
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 169: ['thank', 'you', 'very', 'much', 'for', 'the', 'wonderful', 'dinner', 'last', 'night', '.']
# PRED 169: ゆうべ は とても ありがとう ござ い ま し た 。
# PRED SCORE: -3.6752
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 170: ['i', 'was', 'ten', 'minutes', 'late', 'for', 'school', '.']
# PRED 170: 私 は 学校 に 遅刻 し た 。
# PRED SCORE: -2.2464
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 171: ['how', "'s", 'the', 'weather', '?']
# PRED 171: 天気 どう で す か 。
# PRED SCORE: -2.9223
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 172: ['she', 'worked', 'to', 'excess', '.']
# PRED 172: 彼女 は 働 く ため に 働 い た 。
# PRED SCORE: -0.3928
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 173: ['father', 'took', 'his', 'place', 'at', 'the', 'head', 'of', 'the', 'table', '.']
# PRED 173: 父 は テーブル の 上座 の 自分 の 席 に つ い た 。
# PRED SCORE: -1.7984
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 174: ['he', 'is', 'still', 'alive', '.']
# PRED 174: 彼 は まだ 生き て い る 。
# PRED SCORE: -0.2318
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 175: ['my', 'father', 'put', 'a', 'ladder', 'against', 'the', 'tree', '.']
# PRED 175: 父 は その 木 に 反 し た 。
# PRED SCORE: -3.4692
#
# [2021-01-30 08:58:27,355 INFO]
# SENT 176: ['would', 'you', 'please', 'open', 'the', 'door', '?']
# PRED 176: ドア を 開け て いただけ ま せ ん か 。
# PRED SCORE: -1.3161
#
# [2021-01-30 08:58:27,356 INFO]
# SENT 177: ['i', 'am', 'to', 'have', 'lunch', 'with', 'him', '.']
# PRED 177: 私 は 彼 と 昼食 を と る 予定 で す 。
# PRED SCORE: -4.5207
#
# [2021-01-30 08:58:27,356 INFO]
# SENT 178: ['we', 'need', 'some', 'money', '.']
# PRED 178: お 金 が 欲し い 。
# PRED SCORE: -2.4452
#
# [2021-01-30 08:58:27,356 INFO]
# SENT 179: ['i', 'walk', 'to', 'the', 'park', '.']
# PRED 179: 私 は 公園 まで 歩 い て い く 。
# PRED SCORE: -0.2238
#
# [2021-01-30 08:58:27,356 INFO]
# SENT 180: ['just', 'wait', 'for', 'me', 'there', '.']
# PRED 180: ちょっと そこ に 待 っ て くださ い 。
# PRED SCORE: -3.0825
#
# [2021-01-30 08:58:28,193 INFO]
# SENT 181: ['where', "'s", 'your', 'better', 'half', '?']
# PRED 181: お 手洗い は どこ で す か 。
# PRED SCORE: -3.1192
#
# [2021-01-30 08:58:28,193 INFO]
# SENT 182: ['he', 'is', 'likely', 'to', 'win', 'this', 'game', '.']
# PRED 182: 彼 は この 試合 に 勝 っ て い る 。
# PRED SCORE: -1.7975
#
# [2021-01-30 08:58:28,193 INFO]
# SENT 183: ['i', 'wonder', 'if', 'someone', 'could', 'help', 'me', 'do', 'this', '.']
# PRED 183: 誰 か が これ を し て くれ る かしら 。
# PRED SCORE: -2.2784
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 184: ['there', 'are', 'many', 'movie', 'theaters', 'in', 'this', 'city', '.']
# PRED 184: この 市 に は 多く の 映画 館 が あ る 。
# PRED SCORE: -0.7803
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 185: ['let', "'s", 'meet', 'here', 'again', 'tomorrow', '.']
# PRED 185: 明日 ここ で また 会 い ま しょ う 。
# PRED SCORE: -1.7906
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 186: ['unless', 'it', 'rains', ',', 'i', 'will', 'go', ',', 'too', '.']
# PRED 186: もし 雨 が 降 っ て も 私 は 行 き ま す 。
# PRED SCORE: -2.1766
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 187: ['i', 'love', 'this', 'job', 'from', 'the', 'bottom', 'of', 'my', 'heart', '.']
# PRED 187: 私 は 心 の 底 から この 仕事 を 愛 し て い る 。
# PRED SCORE: -3.6214
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 188: ['i', "'ve", 'never', 'been', 'to', 'such', 'a', 'nice', 'party', '.']
# PRED 188: 私 は こんな い い パーティー に 行 っ た こと が な い 。
# PRED SCORE: -2.3647
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 189: ['they', 'booted', 'him', 'out', 'of', 'school', 'for', 'not', 'studying', '.']
# PRED 189: 彼 ら は 学校 を 勉強 し な い ふり を し た 。
# PRED SCORE: -1.8486
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 190: ['i', "'ll", 'give', 'you', 'a', 'call', 'before', 'i', 'visit', 'you', '.']
# PRED 190: 君 に 訪ね る 前 に 電話 し ま す 。
# PRED SCORE: -3.5689
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 191: ['his', 'story', 'rings', 'true', '.']
# PRED 191: 彼 の 話 は 本当 に な っ た 。
# PRED SCORE: -1.6310
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 192: ['he', 'left', 'a', 'while', 'ago', '.']
# PRED 192: 彼 は その 間 前 に い た 。
# PRED SCORE: -6.1854
#
# [2021-01-30 08:58:28,194 INFO]
# SENT 193: ['what', 'does', 'this', 'kanji', 'mean', '?']
# PRED 193: この フレーズ は どう する の で す か 。
# PRED SCORE: -3.3913
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 194: ['it', 'is', 'necessary', 'for', 'you', 'to', 'go', 'there', 'immediately', '.']
# PRED 194: あなた が すぐ に そこ へ 行 く 必要 が あ る 。
# PRED SCORE: -1.1658
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 195: ['my', 'son', 'shall', 'do', 'the', 'work', '.']
# PRED 195: 私 の 息子 で その 仕事 は や っ て い ま す 。
# PRED SCORE: -2.6452
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 196: ['i', "'d", 'like', 'to', 'have', 'a', 'glass', 'of', 'wine', '.']
# PRED 196: ワイン を いっぱい いただ き た い 。
# PRED SCORE: -2.2387
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 197: ['he', 'lived', 'a', 'simple', 'life', '.']
# PRED 197: 彼 は やさし い 生活 を 送 っ た 。
# PRED SCORE: -2.2568
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 198: ['he', 'had', 'no', 'hat', 'on', '.']
# PRED 198: 彼 に は 帽子 が な かっ た 。
# PRED SCORE: -0.7309
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 199: ['my', 'son', 'has', 'gone', 'to', 'america', 'to', 'study', 'medicine', '.']
# PRED 199: 息子 は 医学 を 勉強 する ため に アメリカ へ 行 っ た 。
# PRED SCORE: -1.9437
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 200: ['i', 'ran', 'out', 'of', 'breath', '.']
# PRED 200: 私 は 息 を 止め た 。
# PRED SCORE: -3.6578
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 201: ['i', 'don', "'t", 'care', 'too', 'much', 'for', 'hot', 'food', '.']
# PRED 201: 暑 い 食物 は あまり 好き で は な い 。
# PRED SCORE: -3.8910
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 202: ['we', 'have', 'to', 'start', 'at', 'once', '.']
# PRED 202: すぐ に 出発 し な けれ ば な ら な い 。
# PRED SCORE: -0.7710
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 203: ['i', 'am', 'just', 'a', 'nobody', '.']
# PRED 203: 私 は ただ ひとり で は な い 。
# PRED SCORE: -4.0267
#
# [2021-01-30 08:58:28,195 INFO]
# SENT 204: ['this', 'question', 'isn', "'t", 'easy', '.']
# PRED 204: この 質問 は 簡単 で は な い 。
# PRED SCORE: -1.6223
#
# [2021-01-30 08:58:28,196 INFO]
# SENT 205: ['may', 'i', 'go', 'home', 'now', '?']
# PRED 205: もう 帰 っ て も い い で す か 。
# PRED SCORE: -2.1001
#
# [2021-01-30 08:58:28,196 INFO]
# SENT 206: ['i', 'like', 'both', '.']
# PRED 206: 両方 とも 好き で す 。
# PRED SCORE: -0.5473
#
# [2021-01-30 08:58:28,196 INFO]
# SENT 207: ['they', 'sat', 'under', 'a', 'tree', '.']
# PRED 207: 彼 ら は 座 っ た 。
# PRED SCORE: -1.3626
#
# [2021-01-30 08:58:28,196 INFO]
# SENT 208: ['i', 'got', 'some', 'sand', 'in', 'my', 'eye', '.']
# PRED 208: 私 は 目 に ハンガー を 入れ た 。
# PRED SCORE: -4.8567
#
# [2021-01-30 08:58:28,196 INFO]
# SENT 209: ['the', 'old', 'man', 'stopped', 'for', 'a', 'moment', 'to', 'rest', '.']
# PRED 209: その 老人 は しばらく の ため に 立ち止ま っ た 。
# PRED SCORE: -5.1370
#
# [2021-01-30 08:58:28,196 INFO]
# SENT 210: ['how', 'many', 'times', 'a', 'month', 'do', 'you', 'write', 'home', '?']
# PRED 210: 何 回 お 手紙 を 書 き ま す か 。
# PRED SCORE: -4.1981
#
# [2021-01-30 08:58:29,012 INFO]
# SENT 211: ['tony', 'was', 'not', 'busy', 'then', '.']
# PRED 211: トニー は 忙し く とも 忙し かっ た 。
# PRED SCORE: -2.3597
#
# [2021-01-30 08:58:29,012 INFO]
# SENT 212: ['all', 'sold', 'out', '!']
# PRED 212: すべて が すべて 飛び出 し た ！
# PRED SCORE: -5.9352
#
# [2021-01-30 08:58:29,012 INFO]
# SENT 213: ['we', "'ll", 'fly', 'there', 'in', '50', 'minutes', '.']
# PRED 213: １０ 分 以内 に そこ で 車 で 行 き ま す 。
# PRED SCORE: -5.3235
#
# [2021-01-30 08:58:29,012 INFO]
# SENT 214: ['she', 'keeps', 'company', 'with', 'a', 'foreign', 'student', '.']
# PRED 214: 彼女 は あ る 外国 人 の 学生 と 付き合 っ て い る 。
# PRED SCORE: -2.1451
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 215: ['yesterday', 'i', 'ran', 'across', 'her', 'at', 'the', 'station', '.']
# PRED 215: 昨日 駅 で 偶然 彼女 に 会 っ た 。
# PRED SCORE: -0.5247
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 216: ['we', 'should', 'be', 'there', 'by', 'noon', '.']
# PRED 216: 私 達 は 正午 に そこ に い る はず だ 。
# PRED SCORE: -2.7516
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 217: ['it', 'was', 'colder', 'yesterday', 'than', 'today', '.']
# PRED 217: 昨日 は より 寒 かっ た 。
# PRED SCORE: -2.3090
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 218: ['you', 'made', 'the', 'same', 'mistake', 'as', 'last', 'time', '.']
# PRED 218: 君 は この 前 と 同じ 間違い を し た 。
# PRED SCORE: -0.8735
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 219: ['my', 'uncle', 'bought', 'me', 'this', 'book', '.']
# PRED 219: おじは 私 に この 本 を 買 っ て くれ た 。
# PRED SCORE: -1.7424
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 220: ['being', 'tired', ',', 'she', 'went', 'to', 'bed', 'early', '.']
# PRED 220: 疲れ て い た の で 、 彼女 は 早 く 寝 た 。
# PRED SCORE: -1.0018
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 221: ['the', 'weather', 'is', 'unusual', 'today', '.']
# PRED 221: 今日 は 変わ っ て い る 。
# PRED SCORE: -2.8530
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 222: ['he', 'is', 'being', 'very', 'careful', '.']
# PRED 222: 彼 は とても 注意 深 く な っ て い る 。
# PRED SCORE: -1.6512
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 223: ['it', 'is', 'hard', 'for', 'an', 'old', 'man', 'to', 'change', 'his', 'way', 'of', 'thinking', '.']
# PRED 223: 老人 が 考え 方 を する と は 難し い 。
# PRED SCORE: -4.6104
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 224: ['you', 'had', 'better', 'go', 'to', 'bed', 'early', '.']
# PRED 224: 早 く 寝 た 方 が い い よ 。
# PRED SCORE: -2.0478
#
# [2021-01-30 08:58:29,013 INFO]
# SENT 225: ['he', 'was', 'injured', 'in', 'the', 'accident', '.']
# PRED 225: 彼 は 事故 で けが を し た 。
# PRED SCORE: -1.1044
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 226: ['well', 'do', 'i', 'remember', 'the', 'man', "'s", 'name', '.']
# PRED 226: 私 は その 男 の 名前 を よく 覚え て い る 。
# PRED SCORE: -2.7457
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 227: ['at', 'last', ',', 'they', 'came', 'to', 'a', 'decision', '.']
# PRED 227: ついに 彼 ら は 決断 を し た 。
# PRED SCORE: -0.4453
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 228: ['he', 'is', 'on', 'the', 'team', '.']
# PRED 228: 彼 は その チーム に 乗 っ て い る 。
# PRED SCORE: -1.5351
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 229: ['why', 'don', "'t", 'you', 'give', 'up', 'smoking', '?']
# PRED 229: たばこ を やめ よ う 。
# PRED SCORE: -3.5878
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 230: ['they', 'were', 'the', 'first', 'to', 'get', 'into', 'the', 'bus', '.']
# PRED 230: 彼 ら が バス に 乗 る 者 に な っ た 。
# PRED SCORE: -2.9713
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 231: ['it', "'s", 'a', 'pity', 'that', 'you', 'should', 'leave', 'japan', '.']
# PRED 231: 君 が 日本 を 離れ る と は 残念 だ 。
# PRED SCORE: -1.0394
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 232: ['that', 'is', 'surprising', '.']
# PRED 232: それ は 驚き で す 。
# PRED SCORE: -1.5066
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 233: ['we', 'came', 'to', 'the', 'town', ',', 'where', 'we', 'stayed', 'for', 'a', 'week', '.']
# PRED 233: 私 たち は 町 へ い っ た 町 に １ 週間 泊ま っ た 。
# PRED SCORE: -5.2381
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 234: ['please', 'leave', 'my', 'things', 'alone', '.']
# PRED 234: 私 の こと に 触 っ て お い て 下さ い 。
# PRED SCORE: -3.1798
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 235: ['but', 'you', 'will', 'write', ',', 'won', "'t", 'you', '?']
# PRED 235: しかし 、 手 を 書 き ま せ ん か 。
# PRED SCORE: -3.9886
#
# [2021-01-30 08:58:29,014 INFO]
# SENT 236: ['it', 'is', 'still', 'immoral', '.']
# PRED 236: まだ 静か な もの だ 。
# PRED SCORE: -5.2918
#
# [2021-01-30 08:58:29,015 INFO]
# SENT 237: ['i', "'d", 'like', 'some', 'more', 'butter', '.']
# PRED 237: バター を もっと 欲し い の で す が 。
# PRED SCORE: -3.2399
#
# [2021-01-30 08:58:29,015 INFO]
# SENT 238: ['that', 'boy', 'is', 'tony', ',', 'isn', "'t", 'he', '?']
# PRED 238: あの 子 は トニー 君 で す ね 。
# PRED SCORE: -0.7761
#
# [2021-01-30 08:58:29,015 INFO]
# SENT 239: ['i', 'like', 'summer', 'the', 'best', '.']
# PRED 239: 私 は 、 夏 が 一番 好き だ 。
# PRED SCORE: -1.7315
#
# [2021-01-30 08:58:29,015 INFO]
# SENT 240: ['the', 'airplane', 'fell', 'to', 'the', 'earth', '.']
# PRED 240: 飛行 機 は 地上 に 落ち た 。
# PRED SCORE: -2.1072
#
# [2021-01-30 08:58:29,875 INFO]
# SENT 241: ['she', 'put', 'down', 'her', 'pen', '.']
# PRED 241: 彼女 は ペン を 置 い た 。
# PRED SCORE: -1.0108
#
# [2021-01-30 08:58:29,875 INFO]
# SENT 242: ['there', 'was', 'almost', 'nothing', 'in', 'the', 'room', '.']
# PRED 242: 部屋 に は ほとんど 何 も な かっ た 。
# PRED SCORE: -1.6284
#
# [2021-01-30 08:58:29,875 INFO]
# SENT 243: ['i', 'do', 'not', 'think', 'it', 'will', 'rain', 'this', 'afternoon', '.']
# PRED 243: 今日 の 午後 は 雨 が 降 ら な い と 思 い ま す 。
# PRED SCORE: -1.9768
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 244: ['the', 'road', 'divides', 'here', 'into', 'two', '.']
# PRED 244: 道 は ここ で ２ つ を 往復 し て い る 。
# PRED SCORE: -6.7213
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 245: ['you', 'have', 'a', 'genius', 'for', 'music', '.']
# PRED 245: 君 に は 音楽 の 才能 が あ る 。
# PRED SCORE: -0.9595
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 246: ['she', 'is', 'great', 'at', 'skiing', '.']
# PRED 246: 彼女 は スキー が 大好き だ 。
# PRED SCORE: -2.1850
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 247: ['he', 'exhausted', 'his', 'money', '.']
# PRED 247: 彼 は その お 金 を 失 っ た 。
# PRED SCORE: -3.0500
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 248: ['it', 'all', 'turned', 'out', 'for', 'the', 'best', 'in', 'the', 'end', '.']
# PRED 248: 結局 、 それ は 結局 最も こと が 分か っ た 。
# PRED SCORE: -8.5588
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 249: ['he', 'stopped', 'smoking', '.']
# PRED 249: 彼 は たばこ を 吸 う の を 止め た 。
# PRED SCORE: -1.7919
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 250: ['he', 'engaged', 'to', 'pay', 'the', 'bill', 'as', 'soon', 'as', 'possible', '.']
# PRED 250: 彼 は でき る だけ 早 く その 勘定 を お 支払い し た 。
# PRED SCORE: -3.5136
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 251: ['he', 'fell', 'behind', 'in', 'his', 'english', 'class', '.']
# PRED 251: 彼 は 英語 の 時間 に 遅れ た 。
# PRED SCORE: -1.2321
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 252: ['he', 'came', 'back', 'to', 'japan', 'for', 'the', 'first', 'time', 'in', 'eight', 'years', '.']
# PRED 252: 彼 は ８ 年間 日本 に 帰 っ て 初めて 帰 っ て き た 。
# PRED SCORE: -3.1093
#
# [2021-01-30 08:58:29,876 INFO]
# SENT 253: ['there', 'is', 'a', 'beautiful', 'walk', 'along', 'the', 'river', '.']
# PRED 253: その 川 に は 美し い 歩 い て い る 。
# PRED SCORE: -3.5945
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 254: ['let', 'me', 'buy', 'you', 'a', 'drink', '.']
# PRED 254: コーヒー を 買 お う 。
# PRED SCORE: -3.4719
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 255: ['i', 'was', 'very', 'worried', 'about', 'her', '.']
# PRED 255: 彼女 は とても 心配 だっ た 。
# PRED SCORE: -2.5144
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 256: ['few', 'people', 'know', 'each', 'other', 'well', '.']
# PRED 256: 人 を 知 っ て い る 人 は ほとんど い な い 。
# PRED SCORE: -3.6959
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 257: ['how', 'did', 'the', 'accident', 'come', 'about', '?']
# PRED 257: その 事故 は どう や っ て 起こ っ た の で す か 。
# PRED SCORE: -1.7160
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 258: ['what', 'time', 'do', 'you', 'leave', 'here', '?']
# PRED 258: あなた は 何 時 に ここ を 出 ま す か 。
# PRED SCORE: -1.9643
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 259: ['mary', 'became', 'a', 'typist', '.']
# PRED 259: メアリー は 牧師 に な っ た 。
# PRED SCORE: -2.5105
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 260: ['my', 'father', 'boasts', 'of', 'the', 'fact', 'that', 'he', 'has', 'never', 'had', 'a', 'traffic', 'accident', '.']
# PRED 260: 彼 は 交通 事故 に あ っ た 真実 を 自慢 する 。
# PRED SCORE: -4.5525
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 261: ['he', 'acquainted', 'me', 'with', 'the', 'change', 'of', 'the', 'plan', '.']
# PRED 261: 彼 は 私 の 計画 の 好み を 教え て くれ た 。
# PRED SCORE: -4.3581
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 262: ['sit', 'down', 'with', 'me', '.']
# PRED 262: 座 っ て 下さ い 。
# PRED SCORE: -1.1049
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 263: ['please', 'send', 'the', 'letter', 'by', 'express', '.']
# PRED 263: その 手紙 を 暗記 し て 下さ い 。
# PRED SCORE: -1.0671
#
# [2021-01-30 08:58:29,877 INFO]
# SENT 264: ['this', 'is', 'an', 'important', 'letter', '.']
# PRED 264: これ は 大切 な 手紙 で す 。
# PRED SCORE: -0.9925
#
# [2021-01-30 08:58:29,878 INFO]
# SENT 265: ['take', 'as', 'many', 'as', 'you', 'want', '.']
# PRED 265: 入用 な だけ 取 り なさ い 。
# PRED SCORE: -3.7041
#
# [2021-01-30 08:58:29,878 INFO]
# SENT 266: ['his', 'novels', 'are', 'too', 'deep', 'for', 'me', '.']
# PRED 266: 彼 の 小説 は 私 に は あまり に も 驚 か な い 。
# PRED SCORE: -3.7290
#
# [2021-01-30 08:58:29,878 INFO]
# SENT 267: ['he', 'relies', 'on', 'his', 'wife', 'financially', '.']
# PRED 267: 彼 は 妻 に 保護 を かけ た 。
# PRED SCORE: -5.5518
#
# [2021-01-30 08:58:29,878 INFO]
# SENT 268: ['you', 'are', 'old', 'enough', 'to', 'be', 'independent', 'of', 'your', 'parents', '.']
# PRED 268: あなた は もう 両親 の 代わり に いけ な い 年頃 だ ね 。
# PRED SCORE: -7.2884
#
# [2021-01-30 08:58:29,878 INFO]
# SENT 269: ['we', 'walked', 'to', 'the', 'river', '.']
# PRED 269: 私 たち は 川 まで 歩 い た 。
# PRED SCORE: -0.7411
#
# [2021-01-30 08:58:29,878 INFO]
# SENT 270: ['i', 'made', 'him', 'change', 'his', 'plan', '.']
# PRED 270: 私 は 彼 に 計画 を 変え た 。
# PRED SCORE: -1.0788
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 271: ['he', 'is', 'the', 'last', 'person', 'to', 'betray', 'his', 'friends', '.']
# PRED 271: 彼 は 決して 友達 を 裏切 る よう な 人 で は な い 。
# PRED SCORE: -0.9700
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 272: ['he', 'could', 'not', 'go', 'on', 'a', 'trip', 'for', 'lack', 'of', 'money', '.']
# PRED 272: 彼 は お 金 の ため に 旅行 に 行け な かっ た 。
# PRED SCORE: -2.4892
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 273: ['i', 'commute', 'to', 'work', 'for', 'an', 'hour', '.']
# PRED 273: 私 は １ 時間 で 働 き ま し た 。
# PRED SCORE: -3.6375
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 274: ['they', 'jumped', 'into', 'the', 'water', 'one', 'after', 'another', '.']
# PRED 274: 彼 ら は 次々 に 水 に 飛び込 ん だ 。
# PRED SCORE: -1.5898
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 275: ['i', 'was', 'used', 'to', 'the', 'heat', '.']
# PRED 275: 私 は 暑 さ に なれ た 。
# PRED SCORE: -1.9081
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 276: ['please', 'drop', 'in', 'on', 'your', 'way', 'home', '.']
# PRED 276: 帰り なさ い 。
# PRED SCORE: -5.0347
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 277: ['he', 'gave', 'up', 'going', 'abroad', '.']
# PRED 277: 彼 は 外国 へ 行 き ま し た 。
# PRED SCORE: -1.5993
#
# [2021-01-30 08:58:30,817 INFO]
# SENT 278: ['don', "'t", 'put', 'the', 'company', 'in', 'danger', '.']
# PRED 278: その 会社 を 危険 に し な い で 下さ い 。
# PRED SCORE: -2.6416
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 279: ['someone', 'is', 'at', 'the', 'door', '.']
# PRED 279: 誰 か が 入り口 に い ま す 。
# PRED SCORE: -1.8029
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 280: ['he', 'gradually', 'came', 'to', 'love', 'his', 'father', '.']
# PRED 280: 彼 は 、 父 を 愛 し て お く よう に な っ た 。
# PRED SCORE: -5.4438
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 281: ['i', 'saw', 'the', 'moon', 'above', 'the', 'roof', '.']
# PRED 281: 私 は 月 の 上 の 月 を 見 た 。
# PRED SCORE: -4.0811
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 282: ['he', 'is', 'supposed', 'to', 'be', 'at', 'home', 'today', '.']
# PRED 282: 彼 は 今日 は 家 に い る はず だ 。
# PRED SCORE: -0.4176
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 283: ['did', 'you', 'practice', 'the', 'piano', 'this', 'morning', '?']
# PRED 283: 今朝 ピアノ 練習 を し ま し た か 。
# PRED SCORE: -0.8267
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 284: ['you', 'must', 'think', 'of', 'your', 'old', 'parents', 'at', 'home', '.']
# PRED 284: あなた は お 年寄り に の 両親 の こと を 考え る べ き で す 。
# PRED SCORE: -6.0548
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 285: ['sad', 'to', 'say', ',', 'her', 'son', 'died', 'young', '.']
# PRED 285: 悲し い 事 に 彼女 彼女 は 若 く な っ た 。
# PRED SCORE: -3.8940
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 286: ['if', 'it', 'rains', 'tomorrow', ',', 'will', 'you', 'stay', 'at', 'home', '?']
# PRED 286: もし 明日 雨 が 降 っ たら 、 家 に い ま す か 。
# PRED SCORE: -3.5491
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 287: ['do', 'you', 'have', 'a', 'student', 'fare', '?']
# PRED 287: あなた は 生徒 が い ま す か 。
# PRED SCORE: -3.4866
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 288: ['let', "'s", 'have', 'dinner', '.']
# PRED 288: 夕食 に し ま しょ う 。
# PRED SCORE: -1.9386
#
# [2021-01-30 08:58:30,818 INFO]
# SENT 289: ['if', 'something', 'happens', ',', 'feel', 'free', 'to', 'call', 'me', '.']
# PRED 289: もし 何 か 起こ っ たら 、 電話 が な る 。
# PRED SCORE: -5.2443
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 290: ['you', 'need', 'not', 'take', 'the', 'trouble', 'to', 'go', '.']
# PRED 290: 君 は 手間 を 立て る 必要 は な い 。
# PRED SCORE: -3.3674
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 291: ['in', 'any', 'case', ',', 'it', "'s", 'none', 'of', 'your', 'business', '.']
# PRED 291: ともかく お 世話 だ 。
# PRED SCORE: -3.5254
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 292: ['three', 'years', 'is', 'a', 'long', 'time', ',', 'i', 'feel', '.']
# PRED 292: 三 年間 長 い の だ 。
# PRED SCORE: -4.7109
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 293: ['would', 'you', 'put', 'on', 'the', 'air', 'conditioning', '?']
# PRED 293: エアコン を 置 き ま す か 。
# PRED SCORE: -3.4115
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 294: ['i', 'didn', "'t", 'want', 'to', 'be', 'defeated', 'in', 'front', 'of', 'my', 'friends', '.']
# PRED 294: 私 は 友人 の 前 で 負け た く な かっ た 。
# PRED SCORE: -2.4461
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 295: ['as', 'soon', 'as', 'you', 'get', 'the', 'wall', 'painted', ',', 'you', 'can', 'go', 'home', '.']
# PRED 295: 壁 に 入 る と すぐ に 帰宅 し なさ い 。
# PRED SCORE: -5.3198
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 296: ['i', "'m", 'very', 'sleepy', 'now', '.']
# PRED 296: 今 、 とても 眠 い 。
# PRED SCORE: -1.2889
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 297: ['above', 'the', 'music', ',', 'i', 'could', 'hear', 'her', 'crying', '.']
# PRED 297: 私 は 音楽 を 読 ん で はじめて 彼女 の 声 が 聞こえ た 。
# PRED SCORE: -7.0675
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 298: ['we', 'had', 'the', 'meeting', 'in', 'this', 'room', 'last', 'friday', '.']
# PRED 298: 私 達 は この 部屋 で この 部屋 で 会 っ た 。
# PRED SCORE: -3.1174
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 299: ['who', 'do', 'you', 'want', 'to', 'speak', 'to', '?']
# PRED 299: あなた は 誰 と 話 し た い の で す か 。
# PRED SCORE: -1.6814
#
# [2021-01-30 08:58:30,819 INFO]
# SENT 300: ['his', 'father', 'eats', 'there', 'twice', 'a', 'week', '.']
# PRED 300: 彼 の 父 は １ 週間 に ２ 回 そこ を ま す 。
# PRED SCORE: -2.7425
#
# [2021-01-30 08:58:31,749 INFO]
# SENT 301: ['he', 'was', 'terribly', 'poor', 'when', 'he', 'was', 'young', '.']
# PRED 301: 彼 は 若 い 頃 は 貧乏 だっ た 。
# PRED SCORE: -2.1262
#
# [2021-01-30 08:58:31,749 INFO]
# SENT 302: ['you', 'may', 'open', 'the', 'window', '.']
# PRED 302: 窓 を 開け て も い い で す よ 。
# PRED SCORE: -1.2080
#
# ...
# PRED SCORE: -4.4229
#
# [2021-01-30 08:58:34,258 INFO]
# SENT 402: ['the', 'sun', 'went', 'behind', 'the', 'clouds', '.']
# PRED 402: 太陽 が 雲 の 中 に 入 っ た 。
# PRED SCORE: -2.2810
#
# [2021-01-30 08:58:34,258 INFO]
# SENT 403: ['his', 'talk', 'was', 'a', 'mere', 'game', '.']
# PRED 403: 彼 の 話 は 全く 試合 に な っ た 。
# PRED SCORE: -2.6331
#
# [2021-01-30 08:58:34,258 INFO]
# SENT 404: ['i', 'dare', 'say', 'it', 'is', 'a', 'lie', '.']
# PRED 404: よく あ る こと だ ろ う 。
# PRED SCORE: -3.8983
#
# [2021-01-30 08:58:34,258 INFO]
# SENT 405: ['she', 'stood', 'up', 'when', 'her', 'teacher', 'came', 'in', '.']
# PRED 405: 彼女 は 先生 が 入 っ て き た とき 立ち上が っ た 。
# PRED SCORE: -1.9664
#
# [2021-01-30 08:58:34,258 INFO]
# SENT 406: ['he', 'likes', 'disney', '.']
# PRED 406: 彼 は トマト が 好き だ 。
# PRED SCORE: -1.2627
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 407: ['the', 'rain', 'came', 'down', 'in', 'buckets', '.']
# PRED 407: 雨 は 炎上 し た 。
# PRED SCORE: -3.3379
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 408: ['don', "'t", 'bother', 'coming', 'in', 'this', 'rain', '.']
# PRED 408: この 雨 に 乗 る な 。
# PRED SCORE: -4.2468
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 409: ['i', "'ll", 'pick', 'you', 'up', 'at', 'your', 'home', '.']
# PRED 409: 車 で あなた の 家 に 迎え に 行 き ま す 。
# PRED SCORE: -3.7306
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 410: ['let', 'me', 'know', 'by', 'wire', '.']
# PRED 410: 知 ら せ て くださ い 。
# PRED SCORE: -3.3812
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 411: ['i', 'will', 'make', 'certain', 'of', 'the', 'situation', '.']
# PRED 411: 私 は 事態 を 確信 し ま す 。
# PRED SCORE: -4.4898
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 412: ['it', "'s", 'our', 'pleasure', '.']
# PRED 412: それ は 我々 の お 楽しみ で す 。
# PRED SCORE: -1.9972
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 413: ['i', 'think', 'it', "'s", 'worth', 'a', 'try', '.']
# PRED 413: それ は や る 価値 が あ る と 思 う 。
# PRED SCORE: -1.2390
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 414: ['he', 'is', 'giving', 'an', 'address', '.']
# PRED 414: 彼 は 演説 を し て い る 。
# PRED SCORE: -3.1392
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 415: ['always', 'keep', 'this', 'dictionary', 'handy', '.']
# PRED 415: いつ も この 辞書 を 使 い ま す 。
# PRED SCORE: -4.2807
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 416: ['next', 'week', ',', 'he', 'is', 'going', 'to', 'new', 'york', 'on', 'business', '.']
# PRED 416: 来週 彼 は 商用 で ニューヨーク へ 行 く 。
# PRED SCORE: -4.1424
#
# [2021-01-30 08:58:34,259 INFO]
# SENT 417: ['the', 'child', 'played', 'the', 'baby', 'to', 'his', 'mother', '.']
# PRED 417: その 子 は 母親 に その 赤ん坊 を うけ た 。
# PRED SCORE: -2.7370
#
# [2021-01-30 08:58:34,260 INFO]
# SENT 418: ['he', 'tried', 'to', 'soothe', 'the', 'angry', 'man', '.']
# PRED 418: 彼 は 怒 っ た 男 を なだめ よ う と し た 。
# PRED SCORE: -1.3120
#
# [2021-01-30 08:58:34,260 INFO]
# SENT 419: ['he', 'wants', 'to', 'dispose', 'of', 'his', 'books', '.']
# PRED 419: 彼 は 本 を 選 び た い 。
# PRED SCORE: -3.5185
#
# [2021-01-30 08:58:34,260 INFO]
# SENT 420: ['you', 'will', 'do', 'exactly', 'as', 'i', 'say', '.']
# PRED 420: 私 の 言 う とおり に し なさ い 。
# PRED SCORE: -4.3597
#
# [2021-01-30 08:58:35,097 INFO]
# SENT 421: ['put', 'that', 'book', 'aside', 'for', 'me', '.']
# PRED 421: その 本 を どけ て 下さ い 。
# PRED SCORE: -3.4055
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 422: ['when', 'she', 'heard', 'it', ',', 'she', 'just', 'cried', '.']
# PRED 422: 彼女 は それ を 聞 い たら 泣 い た 。
# PRED SCORE: -5.2095
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 423: ['i', 'have', 'just', 'now', 'finished', 'doing', 'my', 'english', 'homework', '.']
# PRED 423: 今 は 英語 の 宿題 を し 終え た ところ だ 。
# PRED SCORE: -4.0798
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 424: ['i', 'make', 'it', 'rule', 'never', 'to', 'borrow', 'money', '.']
# PRED 424: 私 は 絶対 に お 金 を 借り な い 。
# PRED SCORE: -3.5229
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 425: ['ken', 'was', 'in', 'japan', 'last', 'year', '.']
# PRED 425: 健 は 去年 日本 に い ま し た 。
# PRED SCORE: -0.7584
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 426: ['i', 'hear', 'he', 'has', 'been', 'ill', 'since', 'last', 'month', '.']
# PRED 426: 彼 は 先月 から ずっと 病気 だっ た そう だ 。
# PRED SCORE: -0.8494
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 427: ['can', 'you', 'sit', 'for', 'the', 'exam', 'next', 'week', '?']
# PRED 427: あなた は 来週 試験 に 座 り ま す か 。
# PRED SCORE: -3.4309
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 428: ['she', 'turned', 'off', 'the', 'lights', '.']
# PRED 428: 彼女 は 明かり を 消 し た 。
# PRED SCORE: -0.5823
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 429: ['i', 'meet', 'him', 'from', 'time', 'to', 'time', '.']
# PRED 429: 私 は 時々 彼 に 会 う 。
# PRED SCORE: -1.3765
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 430: ['i', 'asked', 'her', 'if', 'she', 'could', 'go', 'to', 'the', 'party', '.']
# PRED 430: 私 は 彼女 に パーティー に 行け る か どう か 尋ね た 。
# PRED SCORE: -1.4280
#
# [2021-01-30 08:58:35,098 INFO]
# SENT 431: ['don', "'t", 'eat', 'too', 'much', '.']
# PRED 431: 食べ 過ぎ な い で 下さ い 。
# PRED SCORE: -0.9774
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 432: ['i', 'feel', 'very', 'cold', '.']
# PRED 432: 私 は とても 寒 い 。
# PRED SCORE: -0.5857
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 433: ['i', 'made', 'an', 'effort', 'to', 'finish', 'my', 'work', '.']
# PRED 433: 私 は 仕事 を 終え る ため に 努力 し た 。
# PRED SCORE: -1.1647
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 434: ['i', 'want', 'a', 'book', '.']
# PRED 434: 私 は 本 が ほし い 。
# PRED SCORE: -1.1568
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 435: ['it', "'s", 'touch', 'and', 'go', '.']
# PRED 435: それ は 行 く で しょ う 。
# PRED SCORE: -6.9180
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 436: ['i', 'refuse', 'to', 'answer', 'the', 'question', '.']
# PRED 436: 私 は その 質問 に 答え る こと が でき る 。
# PRED SCORE: -2.4872
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 437: ['would', 'you', 'mind', 'waiting', 'a', 'few', 'minutes', '?']
# PRED 437: 少し 待 っ て いただけ ま せ ん か 。
# PRED SCORE: -1.0512
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 438: ['you', 'brought', 'it', 'on', 'yourself', '.']
# PRED 438: 君 は 自分 で それ を 持 っ て き た 。
# PRED SCORE: -4.4956
#
# [2021-01-30 08:58:35,099 INFO]
# SENT 439: ['how', 'long', 'will', 'you', 'stay', 'in', 'japan', '?']
# PRED 439: いつ まで 日本 に 滞在 し ま す か 。
# PRED SCORE: -2.8606
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 440: ['i', 'can', 'solve', 'this', 'problem', '.']
# PRED 440: 私 は この 問題 を 解け ま す 。
# PRED SCORE: -0.9748
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 441: ['she', 'retorted', 'against', 'him', '.']
# PRED 441: 彼女 は 彼 に 反対 し た 。
# PRED SCORE: -1.6418
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 442: ['his', 'composition', 'was', 'free', 'from', 'mistakes', '.']
# PRED 442: 彼 の 作文 は 誤り が な かっ た 。
# PRED SCORE: -0.8729
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 443: ['we', 'got', 'to', 'know', 'each', 'other', 'rather', 'well', 'on', 'our', 'recent', 'trip', '.']
# PRED 443: 私 たち は 旅行 の 途中 で 互い に 知り合い に な っ た 。
# PRED SCORE: -4.6427
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 444: ['i', 'want', 'to', 'get', 'in', 'touch', 'with', 'him', '.']
# PRED 444: 私 は 彼 と 連絡 を 取 り た い 。
# PRED SCORE: -1.6546
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 445: ['is', 'there', 'any', 'need', 'for', 'me', 'to', 'go', 'there', '?']
# PRED 445: 私 が そこ に 行 く 必要 は あ り ま す か 。
# PRED SCORE: -1.1252
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 446: ['i', 'have', 'no', 'face', 'to', 'turn', 'to', '.']
# PRED 446: 私 に は 頼れ る ところ が な い 。
# PRED SCORE: -1.6830
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 447: ['he', 'is', 'gone', 'on', 'that', 'girl', '.']
# PRED 447: 彼 は その 少女 に 行 っ て い ま す 。
# PRED SCORE: -3.2355
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 448: ['all', 'boys', 'like', 'to', 'play', 'baseball', '.']
# PRED 448: みんな は 野球 を する の が 好き だ 。
# PRED SCORE: -2.1890
#
# [2021-01-30 08:58:35,100 INFO]
# SENT 449: ['don', "'t", 'give', 'in', '.']
# PRED 449: 中 に 入れ て は いけ な い 。
# PRED SCORE: -2.3494
#
# [2021-01-30 08:58:35,101 INFO]
# SENT 450: ['i', 'waited', 'and', 'waited', '.']
# PRED 450: 私 は 待 っ た が 、 待 っ た 。
# PRED SCORE: -3.2156
#
# [2021-01-30 08:58:35,961 INFO]
# SENT 451: ['because', 'of', 'illness', ',', 'she', 'couldn', "'t", 'come', '.']
# PRED 451: 病気 の ため 彼女 は 来 られ な かっ た 。
# PRED SCORE: -0.2775
#
# [2021-01-30 08:58:35,961 INFO]
# SENT 452: ['i', 'bought', 'a', 'watch', 'with', 'cash', '.']
# PRED 452: 私 は 即金 で 時計 を 買 っ た 。
# PRED SCORE: -1.9736
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 453: ['his', 'bicycle', 'is', 'blue', '.']
# PRED 453: 彼 の 自転 車 は 青 い 。
# PRED SCORE: -0.1783
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 454: ['this', 'door', 'won', "'t", 'shut', '.']
# PRED 454: この ドア は どう し て も 閉ま ら な い 。
# PRED SCORE: -0.3063
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 455: ['we', 'must', 'take', 'this', 'matter', 'into', 'account', 'as', 'a', 'whole', '.']
# PRED 455: 我々 は この こと を 全体 的 に 考え な けれ ば な ら な い 。
# PRED SCORE: -3.6416
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 456: ['are', 'you', 'for', 'the', 'war', 'or', 'against', 'it', '?']
# PRED 456: 君 は 戦争 に 合 い ま す か それ と 反対 で す か 。
# PRED SCORE: -4.5115
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 457: ['it', 'is', 'probable', 'that', 'he', 'forget', 'about', 'it', '.']
# PRED 457: それ に つ い て 彼 が 言 う こと を 忘れ て い る 。
# PRED SCORE: -4.3529
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 458: ['he', 'said', 'that', 'he', 'goes', 'for', 'a', 'long', 'walk', 'every', 'morning', '.']
# PRED 458: 彼 は 毎朝 は 散歩 に 出かけ る と 言 っ た 。
# PRED SCORE: -2.1132
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 459: ['i', 'was', 'astonished', 'at', 'the', 'news', '.']
# PRED 459: 私 は その 知らせ に びっくり し た 。
# PRED SCORE: -0.6101
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 460: ['how', 'far', 'is', 'it', 'from', 'here', 'to', 'tokyo', '?']
# PRED 460: ここ から 東京 まで どの くらい 離れ て い ま す か 。
# PRED SCORE: -1.9009
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 461: ['sorry', ',', 'i', 'wish', 'you', 'wouldn', "'t", '.']
# PRED 461: ごめん 、 そう い わ な かっ たら い い けど 。
# PRED SCORE: -6.5862
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 462: ['i', 'arrived', 'at', 'narita', 'airport', 'this', 'morning', '.']
# PRED 462: 私 は 今夕 空港 に 着 い た 。
# PRED SCORE: -2.8486
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 463: ['he', 'promised', 'not', 'to', 'tell', '.']
# PRED 463: 彼 は 言 わ な い と 約束 し た 。
# PRED SCORE: -1.4929
#
# [2021-01-30 08:58:35,962 INFO]
# SENT 464: ['he', 'looks', 'young', 'considering', 'his', 'age', '.']
# PRED 464: 彼 は 年 の 割 に は 若 く 見え る 。
# PRED SCORE: -0.9877
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 465: ['they', 'made', 'me', 'go', 'there', 'alone', '.']
# PRED 465: 彼 ら は 私 を 一人 で そこ へ 行 か せ た 。
# PRED SCORE: -1.1275
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 466: ['let', 'me', 'know', 'the', 'details', '.']
# PRED 466: こしょう を 知 ら せ て くださ い 。
# PRED SCORE: -4.2173
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 467: ['you', 'are', 'absolutely', 'right', '.']
# PRED 467: 全く あなた の 言 う とおり で す ね 。
# PRED SCORE: -2.6053
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 468: ['his', 'work', 'finished', ',', 'he', 'went', 'to', 'bed', '.']
# PRED 468: 彼 は 仕事 を 終え た 後 で 就寝 し た 。
# PRED SCORE: -2.6505
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 469: ['my', 'sister', 'washes', 'her', 'hair', 'every', 'morning', '.']
# PRED 469: 私 の 姉 は 毎朝 髪 を 洗 う 。
# PRED SCORE: -0.6768
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 470: ['please', 'give', 'me', 'help', 'in', 'taking', 'this', 'down', '.']
# PRED 470: この 辺 で 手伝 っ て 下さ い 。
# PRED SCORE: -5.0637
#
# [2021-01-30 08:58:35,963 INFO]
# SENT 471: ['i', 'do', 'not', 'care', 'for', 'him', '.']
# PRED 471: 私 は 彼 の こと は 気 に し な い 。
# PRED SCORE: -2.2179
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 472: ['nothing', 'can', 'be', 'better', 'than', 'that', '.']
# PRED 472: あれ より も 良 い もの は な い 。
# PRED SCORE: -3.0340
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 473: ['this', 'will', 'do', 'for', 'now', '.']
# PRED 473: これ で 間に合 う で しょ う 。
# PRED SCORE: -1.5997
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 474: ['i', 'hope', 'it', 'will', 'be', 'the', 'only', 'one', '.']
# PRED 474: それ が い い と 思 い ま す 。
# PRED SCORE: -3.6682
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 475: ['she', 'has', 'a', 'son', 'who', 'is', 'a', 'doctor', '.']
# PRED 475: 彼女 に は 医者 は い る 息子 が い る 。
# PRED SCORE: -3.7932
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 476: ['the', 'teacher', 'looked', 'over', 'the', 'examination', 'papers', '.']
# PRED 476: 先生 は 答案 を 調べ た 。
# PRED SCORE: -0.6315
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 477: ['he', 'had', 'the', 'luck', 'to', 'catch', 'the', 'train', '.']
# PRED 477: 彼 は その 列車 に 乗 る ため に 幸運 に な っ た 。
# PRED SCORE: -3.2731
#
# [2021-01-30 08:58:35,964 INFO]
# SENT 478: ['i', 'will', 'go', 'on', 'foot', '.']
# PRED 478: 私 は 歩 い て い き ま す 。
# PRED SCORE: -1.5212
#
# [2021-01-30 08:58:35,965 INFO]
# SENT 479: ['she', 'was', 'sore', 'at', 'me', 'for', 'being', 'late', '.']
# PRED 479: 彼女 は 私 が 遅れ た こと が 大好き だっ た 。
# PRED SCORE: -4.4947
#
# [2021-01-30 08:58:35,965 INFO]
# SENT 480: ['i', "'d", 'better', 'not', 'eat', 'that', '.']
# PRED 480: で も 食べ な い で 下さ い 。
# PRED SCORE: -5.5911
#
# /usr/local/lib/python3.6/dist-packages/OpenNMT_py-1.2.0-py3.6.egg/onmt/translate/beam_search.py:209: UserWarning: An output with one or more elements was resized since it had shape [100], which does not match the required output shape [20, 5].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  /pytorch/aten/src/ATen/native/Resize.cpp:19.)
#   torch.mul(self.topk_scores, length_penalty, out=self.topk_log_probs)
# [2021-01-30 08:58:36,556 INFO]
# SENT 481: ['i', 'will', 'gladly', 'help', 'you', '.']
# PRED 481: 私 は あなた を 援助 し ま す 。
# PRED SCORE: -3.9837
#
# [2021-01-30 08:58:36,556 INFO]
# SENT 482: ['i', 'went', 'fishing', 'in', 'the', 'river', 'yesterday', '.']
# PRED 482: 私 は 昨日 川 へ 魚釣り に 行 っ た 。
# PRED SCORE: -2.5836
#
# [2021-01-30 08:58:36,556 INFO]
# SENT 483: ['i', 'have', 'been', 'to', 'the', 'station', '.']
# PRED 483: 駅 に 行 っ て き た ところ で す 。
# PRED SCORE: -2.1800
#
# [2021-01-30 08:58:36,556 INFO]
# SENT 484: ['he', 'put', 'some', 'coins', 'in', 'the', 'box', '.']
# PRED 484: 彼 は その 箱 に かさ を 入れ た 。
# PRED SCORE: -3.0299
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 485: ['this', 'is', 'a', 'book', '.']
# PRED 485: これ が 本 で す 。
# PRED SCORE: -0.8607
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 486: ['he', 'had', 'the', 'table', 'to', 'himself', '.']
# PRED 486: 彼 は 一人 で テーブル を つけ た 。
# PRED SCORE: -3.1738
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 487: ['i', 'reached', 'school', 'before', 'the', 'rain', 'started', '.']
# PRED 487: 雨 の 前 に 学校 に 着 い た 。
# PRED SCORE: -1.2512
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 488: ['the', 'country', 'was', 'gearing', 'up', 'for', 'war', '.']
# PRED 488: その 国 は 戦争 で 分裂 し て い た 。
# PRED SCORE: -2.3014
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 489: ['this', 'song', 'is', 'familiar', 'to', 'me', '.']
# PRED 489: この 歌 は 私 に よく 知 ら れ て い る 。
# PRED SCORE: -0.4380
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 490: ['time', 'will', 'tell', 'which', 'is', 'right', '.']
# PRED 490: 正し い もの は 正し い 。
# PRED SCORE: -3.8413
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 491: ['did', 'you', 'clean', 'your', 'room', '?']
# PRED 491: 部屋 は 掃除 し ま し た か 。
# PRED SCORE: -0.8298
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 492: ['he', 'is', 'good', 'at', 'tennis', '.']
# PRED 492: 彼 は テニス が うま い 。
# PRED SCORE: -0.2059
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 493: ['he', 'is', 'the', 'last', 'person', 'to', 'speak', 'ill', 'of', 'others', '.']
# PRED 493: 彼 は 他人 の 悪口 を 言 う 人 で は な い 。
# PRED SCORE: -1.7178
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 494: ['may', 'i', 'have', 'a', 'road', 'map', '?']
# PRED 494: 道 を 地図 で いただけ ま す か 。
# PRED SCORE: -1.6899
#
# [2021-01-30 08:58:36,557 INFO]
# SENT 495: ['i', 'cannot', 'make', 'anything', 'of', 'what', 'he', 'says', '.']
# PRED 495: 私 は 彼 の 言 う こと が 何 で も 理解 でき な い 。
# PRED SCORE: -2.2394
#
# [2021-01-30 08:58:36,558 INFO]
# SENT 496: ['it', 'took', 'a', 'long', 'time', 'to', 'accustom', 'myself', 'to', 'the', 'noise', '.']
# PRED 496: その 騒音 に は 口 を 出 す 時間 が 長 く な っ た 。
# PRED SCORE: -6.2143
#
# [2021-01-30 08:58:36,558 INFO]
# SENT 497: ['you', 'ought', 'not', 'to', 'say', 'such', 'a', 'thing', '.']
# PRED 497: 君 は そんな こと を 言 う べ き で は な い 。
# PRED SCORE: -1.3385
#
# [2021-01-30 08:58:36,558 INFO]
# SENT 498: ['what', 'good', 'books', 'these', 'are', '.']
# PRED 498: これ ら は 何 と い う 世の中 な 本 で す 。
# PRED SCORE: -4.2428
#
# [2021-01-30 08:58:36,558 INFO]
# SENT 499: ['for', 'all', 'his', 'efforts', ',', 'he', 'didn', "'t", 'succeed', '.']
# PRED 499: 彼 は 努力 し た が 成功 し な かっ た 。
# PRED SCORE: -1.4134
#
# [2021-01-30 08:58:36,558 INFO]
# SENT 500: ['where', 'do', 'you', 'come', 'from', '?']
# PRED 500: どこ から 来 ま し た か 。
# PRED SCORE: -1.5864
#
# [2021-01-30 08:58:36,558 INFO] PRED AVG SCORE: -0.2559, PRED PPL: 1.2916

# %% [markdown]
# ##BLEU による評価
# 正解（参照訳）のファイルを第一引数に、システムの出力をリダイレクト（<）で渡します。

# %%
# !perl tools/multi-bleu.perl small_parallel_enja/test.ja < pred.txt
# Out:
# BLEU = 36.74, 66.4/44.9/31.6/23.0 (BP=0.957, ratio=0.958, hyp_len=5397, ref_len=5635)

# %%
cat pred.txt
# Out:
# 彼 ら は ついに それ を 事実 と し た 。
# 彼 は 泳 ぐ 気 が し な かっ た 。
# 彼 は 姉 に 劣 ら ず 頭 が い い 。
# １０ 時 前 に 戻 ら な けれ ば な ら な い 。
# 働 き 過ぎ た 。
# 彼女 は 私 達 の 隣 に 住 ん で い る 。
# お 答え 下さ い 。
# 私 は 今 の ところ に 住 ん で い る 人 で す 。
# この 試合 は 間違い だ 。
# この 説明 を し て くれ ま せ ん か 。
# 彼女 は 先生 が 好き で す 。
# 商売 は 商売 で す 。
# この 靴 は あなた に 二 年間 あ る だ ろ う 。
# 彼 は 息子 に 会 で その 会合 に 出席 し た 。
# あなた の 仲間 に 行 く よう に し なさ い 。
# 仕事 の 終わり に 働 く 。
# 私 は 彼女 の 顔 を まとも に 見 る こと が でき な かっ た 。
# 日曜 の 朝教会 に は 誰 も い る 。
# 時計 を ２ 分 後 に 出 し ま す 。
# あれ が 昨日 私 が 会 っ た 少年 で す 。
# １０ 年 と は 待 つ の は 長 い 時間 だ 。
# 私 は 偶然 彼 に 東京 で 会 っ た 。
# 私 は よく 川 で 泳ぎ に 行 き ま す 。
# 彼 は 大声 で 助け を 求め た 。
# 彼 は その 子 を 火 から 救 っ た 。
# 私 は 彼 の 提案 に 同意 でき な い 。
# 私 たち は 何 度 も その 手紙 を 読 ん だ 。
# 私 は あなた に 会え て うれし い 。
# お 父 さん に お 手伝い くださ い 。
# 彼 ら は その その 提案 を 断念 し た 。
# 私 は 特別 な こと が い い 。
# それ 以来 彼 に は 誰 も 見 な かっ た 。
# 彼女 は 昔 、 羽振り が よ かっ た 。
# それ を ほか の 少年 たち に 回 し て 下さ い 。
# 私 は 彼 の 名前 を 心 に 銘記 し て い る 。
# 私 は あなた と 結婚 し た い 。
# 今 すぐ 彼 ら を 見かけ る だ ろ う 。
# 地球 は 強 く な っ た 。
# どちら が 欲し い か 私 に 教え て 下さ い 。
# 彼 が どこ に い たら よ かっ た か なあ 。
# 私 達 は 先週 数学 の 試験 を 受け た 。
# 勘定 書 を 頼 む よ 。
# 私 は 聞 い て 何 も 聞 い た 。
# 彼女 は その 男 と 結婚 し な かっ た 。
# 彼 は あまり 本 を 読 ん で い な い 。
# 彼女 に は 悪意 が な い 。
# その 夏 は 非常 に 単調 だ 。
# 彼 は 私 に その 手紙 を ペン で 書 か せ た 。
# 彼 は 読書 に 飽き た 。
# ここ に お 名前 と お 名前 を お 書 き くださ い 。
# 彼女 は 上手 に ピアノ を 弾 い た 。
# 私 は まだ 注文 し ま し た 。
# この 図書 館 に は 非常 に たくさん の 本 が あ る 。
# あらゆる 機会 を 利用 す べ き だ 。
# あなた の 街 に は 何 枚 の 脚 が あ り ま す か 。
# 私 は 映画 が 好き で は な い 。
# 彼女 は 私 が 約束 を 忘れ た 時 に とても 怒 っ た 。
# 君 の 年 の 人々 は しばしば この 問題 を 解 く 。
# 私 は 君 の 車 が 好き で す 。
# 彼女 は 川 の 中 で ボート を 見 て い た 。
# 彼 が 来る か どう か は 私 が 行 き ま す 。
# 私 は 母 ほど 早 く 起き な い 。
# で さえ 赤 い 。
# 忘れ ず に 私 を 入れ て くれ 。
# きみ だけ で す 。
# 私 は その 点 に 反対 し て い る 。
# 私 は 月曜 日 まで に ここ に い ま す 。
# 彼女 は クラス で 一番 幸せ だ 。
# なんて すばらし い 結果 な の だ ろ う 。
# 時間 ほど 大切 な もの は な い 。
# あなた は そんな に 早 く くる 必要 は な かっ た の で す 。
# 私 は いく つ か 質問 が あ っ た 。
# 彼女 は 自分 の 人生 に 満足 し て い る と 言 っ た 。
# 昨夜 会 っ た 時 は 、 夜 は ８ 時 だっ た 。
# 人 の 人生 は 液体 で あ る 。
# そんな よう な もの を 要求 する な 。
# 彼 ら は 独創 的 に とても でき る 。
# 私 は 夕食 を 食べ ま し た 。
# 今日 は 暑 い 。
# 彼 は サイコ だ 。
# 彼 は いつ も 彼女 の 味方 を する 。
# ジェーン は 、 いつ も とても 金持ち だっ た 。
# 彼 は 何 と 悪 い 子 な の だ ろ う 。
# 彼 は 私 たち が いつ で も その 男 を 呼 ん で い る 。
# 実際 は 彼 は い い やつ だ 。
# その 答え は どこ に あ る の で す か 。
# 試験 の 準備 を し た ほう が い い で す よ 。
# 物 が よく 見え ま せ ん 。
# 車 を 借り られ ま す か 。
# 賢 い 人 なら 、 その よう な 人 で は な い だ ろ う 。
# 彼 は 私 に 病気 だ と 言 っ た 。
# 庭 に は 誰 も い な かっ た 。
# 私 達 の 大学 は 駅 から 遠 い 。
# 彼 は 手紙 を 書 き 続け て い た 。
# 彼 は その こと に つ い て 彼女 に 話 し た 。
# 私 に それ を 見せ て 下さ い 。
# 彼 は 目 を 閉じ て そこ に 座 っ た 。
# 若 い 頃 は 一生 懸命 働 く べ き で す 。
# 彼 は ぶっきらぼう な 出発 を し た 。
# この よう に し て 事故 が 起こ っ た の で す 。
# ジェーン は 若 い と い う 時 の スチュワーデス だっ た 。
# 彼 は 妻 を こわ が っ た 。
# 駅 まで どの くらい あ り ま す か 。
# 彼 は この 上 な く 貧乏 な 男 だ 。
# 約束 を 破 る べ き で は な い 。
# 私 たち は 自分 の 家 を 持 っ て い る 。
# あなた は 私 に 不 可能 な こと を する よう に 頼 ん で 下さ い 。
# この 荷物 は あの 手 の ３ 倍 重 く な っ た 。
# ロンドン に い た 良 い 日 に 戻 り ま す 。
# 私 は タクシー から 降り た 。
# 今晩 は 話 す 予定 で す 。
# その 少女 たち は 吉雄 と し て 忙し い 。
# 学校 に は 少年 より ほか に たくさん の 女の子 が い る 。
# 日 は 長 く 長 く な っ て き ま す 。
# テーブル の 上 に 置 い て お き なさ い 。
# あなた は 今日 何 を する つもり で す か 。
# 昨夜 は 強 く 雨 が 降 っ た 。
# 今晩 映画 に 行 く の は どう で す か 。
# あなた に は 援助 する 権利 は な い 。
# もちろん 私 が そこ へ 行 き ま す 。
# 彼 ら は 部屋 の 中 で 少し 眠 っ た 。
# 考え を 話 し なさ い 。
# その 老人 は 先週 死 ん だ 。
# 何 が 起こ っ た 聞 い て びっくり し た 。
# 彼 の 手 は 寒 さ の ため に 青 く な っ た 。
# 私 は 彼女 を 少し も 理解 でき な かっ た 。
# 私 の 勉強 は 許 さ れ て い る 。
# 宿題 を 忘れ た の は 君 が 不 注意 だっ た ね 。
# 私 の 家 の 前 に 公園 が あ る 。
# 私 は まったく 疲れ て い な い 。
# 私 が 会 う と は 彼 は 思 わ な い 。
# ジェーン は 母 と まったく 同じ よう に 美人 だ 。
# 一体 どう し た ん だ 。
# と 彼女 と スキー に 行 き た い 。
# 暴動 は とても 難し く て 私 に は 嫌い だ 。
# 彼女 の 先生 は けんか を する 。
# ここ に 君 宛 の 手紙 が あ る 。
# 言葉 の 意味 が 燃え て い る 。
# スポーツ を し て も い い で す か 。
# もう すっかり 終わ っ た 。
# 私 は 毎朝 六 時 に 起き ま す 。
# その 銀行 は 昨晩 、 その 銀行 に 上が っ た 。
# 私 は 彼女 と 結婚 し た い と 結婚 し た い 。
# 彼 は 私 たち に 静か に する よう に 言 っ た 。
# 彼 は 偉大 な 政治 家 だ 。
# あなた は お 父 さん を 誇り に 思 い ま す か 。
# コンピューター は 簡単 に その 仕事 を でき る 。
# この 件 は あの 件 と あ っ て い る 。
# 庭 に は 古 い 木 が あ る 。
# 猫 も 好き で は あ り ま せ ん 。
# 私 の 兄 は 今 宗教 を し ま せ ん 。
# 彼 は 頭 を 下げ さえ し な かっ た 。
# 彼 は 次 の バス 停 で 降り た 。
# これ を し た か 誰 も わか ら な い 。
# 彼女 は 私 に 自分 の 部屋 を 見せ た 。
# 彼 は 私 に どちら の 道 を 行 け ば よ い か 尋ね た 。
# 彼女 は しきり に 結果 を 知 り たが っ て い る 。
# あの 庭 に は 何 の 花 も あ る 。
# 彼 は 青 い 上着 を 着 て い た 。
# だれ ひとり が 来る 。
# 彼 は 暖か い 。
# 彼女 は 学校 へ 行 く 日 に 言い切 っ た 。
# 将来 もっと 注意 し て 下さ い 。
# 私 は 彼女 と 連絡 を 取 る の が 大変 だっ た 。
# その 警官 の 速 い 結果 は 私 たち に 驚 い た 。
# ここ に 着 い たら すぐ に 連絡 し なさ い 。
# 彼 が 家出 を し た の は 事実 だ 。
# その ニュース は 彼女 が とても 悲し く な っ た 。
# ゆうべ は とても ありがとう ござ い ま し た 。
# 私 は 学校 に 遅刻 し た 。
# 天気 どう で す か 。
# 彼女 は 働 く ため に 働 い た 。
# 父 は テーブル の 上座 の 自分 の 席 に つ い た 。
# 彼 は まだ 生き て い る 。
# 父 は その 木 に 反 し た 。
# ドア を 開け て いただけ ま せ ん か 。
# 私 は 彼 と 昼食 を と る 予定 で す 。
# お 金 が 欲し い 。
# 私 は 公園 まで 歩 い て い く 。
# ちょっと そこ に 待 っ て くださ い 。
# お 手洗い は どこ で す か 。
# 彼 は この 試合 に 勝 っ て い る 。
# 誰 か が これ を し て くれ る かしら 。
# この 市 に は 多く の 映画 館 が あ る 。
# 明日 ここ で また 会 い ま しょ う 。
# もし 雨 が 降 っ て も 私 は 行 き ま す 。
# 私 は 心 の 底 から この 仕事 を 愛 し て い る 。
# 私 は こんな い い パーティー に 行 っ た こと が な い 。
# 彼 ら は 学校 を 勉強 し な い ふり を し た 。
# 君 に 訪ね る 前 に 電話 し ま す 。
# 彼 の 話 は 本当 に な っ た 。
# 彼 は その 間 前 に い た 。
# この フレーズ は どう する の で す か 。
# あなた が すぐ に そこ へ 行 く 必要 が あ る 。
# 私 の 息子 で その 仕事 は や っ て い ま す 。
# ワイン を いっぱい いただ き た い 。
# 彼 は やさし い 生活 を 送 っ た 。
# 彼 に は 帽子 が な かっ た 。
# 息子 は 医学 を 勉強 する ため に アメリカ へ 行 っ た 。
# 私 は 息 を 止め た 。
# 暑 い 食物 は あまり 好き で は な い 。
# すぐ に 出発 し な けれ ば な ら な い 。
# 私 は ただ ひとり で は な い 。
# この 質問 は 簡単 で は な い 。
# もう 帰 っ て も い い で す か 。
# 両方 とも 好き で す 。
# 彼 ら は 座 っ た 。
# 私 は 目 に ハンガー を 入れ た 。
# その 老人 は しばらく の ため に 立ち止ま っ た 。
# 何 回 お 手紙 を 書 き ま す か 。
# トニー は 忙し く とも 忙し かっ た 。
# すべて が すべて 飛び出 し た ！
# １０ 分 以内 に そこ で 車 で 行 き ま す 。
# 彼女 は あ る 外国 人 の 学生 と 付き合 っ て い る 。
# 昨日 駅 で 偶然 彼女 に 会 っ た 。
# 私 達 は 正午 に そこ に い る はず だ 。
# 昨日 は より 寒 かっ た 。
# 君 は この 前 と 同じ 間違い を し た 。
# おじは 私 に この 本 を 買 っ て くれ た 。
# 疲れ て い た の で 、 彼女 は 早 く 寝 た 。
# 今日 は 変わ っ て い る 。
# 彼 は とても 注意 深 く な っ て い る 。
# 老人 が 考え 方 を する と は 難し い 。
# 早 く 寝 た 方 が い い よ 。
# 彼 は 事故 で けが を し た 。
# 私 は その 男 の 名前 を よく 覚え て い る 。
# ついに 彼 ら は 決断 を し た 。
# 彼 は その チーム に 乗 っ て い る 。
# たばこ を やめ よ う 。
# 彼 ら が バス に 乗 る 者 に な っ た 。
# 君 が 日本 を 離れ る と は 残念 だ 。
# それ は 驚き で す 。
# 私 たち は 町 へ い っ た 町 に １ 週間 泊ま っ た 。
# 私 の こと に 触 っ て お い て 下さ い 。
# しかし 、 手 を 書 き ま せ ん か 。
# まだ 静か な もの だ 。
# バター を もっと 欲し い の で す が 。
# あの 子 は トニー 君 で す ね 。
# 私 は 、 夏 が 一番 好き だ 。
# 飛行 機 は 地上 に 落ち た 。
# 彼女 は ペン を 置 い た 。
# 部屋 に は ほとんど 何 も な かっ た 。
# 今日 の 午後 は 雨 が 降 ら な い と 思 い ま す 。
# 道 は ここ で ２ つ を 往復 し て い る 。
# 君 に は 音楽 の 才能 が あ る 。
# 彼女 は スキー が 大好き だ 。
# 彼 は その お 金 を 失 っ た 。
# 結局 、 それ は 結局 最も こと が 分か っ た 。
# 彼 は たばこ を 吸 う の を 止め た 。
# 彼 は でき る だけ 早 く その 勘定 を お 支払い し た 。
# 彼 は 英語 の 時間 に 遅れ た 。
# 彼 は ８ 年間 日本 に 帰 っ て 初めて 帰 っ て き た 。
# その 川 に は 美し い 歩 い て い る 。
# コーヒー を 買 お う 。
# 彼女 は とても 心配 だっ た 。
# 人 を 知 っ て い る 人 は ほとんど い な い 。
# その 事故 は どう や っ て 起こ っ た の で す か 。
# あなた は 何 時 に ここ を 出 ま す か 。
# メアリー は 牧師 に な っ た 。
# 彼 は 交通 事故 に あ っ た 真実 を 自慢 する 。
# 彼 は 私 の 計画 の 好み を 教え て くれ た 。
# 座 っ て 下さ い 。
# その 手紙 を 暗記 し て 下さ い 。
# これ は 大切 な 手紙 で す 。
# 入用 な だけ 取 り なさ い 。
# 彼 の 小説 は 私 に は あまり に も 驚 か な い 。
# 彼 は 妻 に 保護 を かけ た 。
# あなた は もう 両親 の 代わり に いけ な い 年頃 だ ね 。
# 私 たち は 川 まで 歩 い た 。
# 私 は 彼 に 計画 を 変え た 。
# 彼 は 決して 友達 を 裏切 る よう な 人 で は な い 。
# 彼 は お 金 の ため に 旅行 に 行け な かっ た 。
# 私 は １ 時間 で 働 き ま し た 。
# 彼 ら は 次々 に 水 に 飛び込 ん だ 。
# 私 は 暑 さ に なれ た 。
# 帰り なさ い 。
# 彼 は 外国 へ 行 き ま し た 。
# その 会社 を 危険 に し な い で 下さ い 。
# 誰 か が 入り口 に い ま す 。
# 彼 は 、 父 を 愛 し て お く よう に な っ た 。
# 私 は 月 の 上 の 月 を 見 た 。
# 彼 は 今日 は 家 に い る はず だ 。
# 今朝 ピアノ 練習 を し ま し た か 。
# あなた は お 年寄り に の 両親 の こと を 考え る べ き で す 。
# 悲し い 事 に 彼女 彼女 は 若 く な っ た 。
# もし 明日 雨 が 降 っ たら 、 家 に い ま す か 。
# あなた は 生徒 が い ま す か 。
# 夕食 に し ま しょ う 。
# もし 何 か 起こ っ たら 、 電話 が な る 。
# 君 は 手間 を 立て る 必要 は な い 。
# ともかく お 世話 だ 。
# 三 年間 長 い の だ 。
# エアコン を 置 き ま す か 。
# 私 は 友人 の 前 で 負け た く な かっ た 。
# 壁 に 入 る と すぐ に 帰宅 し なさ い 。
# 今 、 とても 眠 い 。
# 私 は 音楽 を 読 ん で はじめて 彼女 の 声 が 聞こえ た 。
# 私 達 は この 部屋 で この 部屋 で 会 っ た 。
# あなた は 誰 と 話 し た い の で す か 。
# 彼 の 父 は １ 週間 に ２ 回 そこ を ま す 。
# 彼 は 若 い 頃 は 貧乏 だっ た 。
# 窓 を 開け て も い い で す よ 。
# 運転 は 速 すぎ る 。
# 私 は 彼 と 一緒 に 遊 ぼ う 。
# 私 は 男 で す 。
# 滞在 目的 は 何 で す か 。
# バス 停 は どこ で あ る か 教え て 下さ い 。
# もし あなた が けれ ば 、 あなた は 行 か な けれ ば な ら な い 。
# 私 は 君 に 同意 し な い よう に 腹 を 立て て い な い 。
# わが チーム が 負け た 理由 を 説明 でき ま す か 。
# 私 は この 日曜 日 に 勤務 中 で す 。
# あなた は この こと を お 送り し な く て は な ら な い 。
# 彼 ら は その 家 を 建て る の に ２ 年間 かか っ た 。
# 私 は カナダ で 友人 に 会 い た い 。
# 前 も っ て お 知らせ し ま す 。
# 私 は それ を し な い だ ろ う と 思 っ た 。
# 時間 を 無駄 に 使 う べ き で は な い 。
# 嘘 を つ い て は いけ な い ！
# 彼 に この 箱 を 運 ば な い よう に し ま す 。
# 学校 に 行 く 代わり に 彼 は 家 に い た 。
# ジム は 弁護 士 で は な い 。
# もし 木 が あ れ ば 、 ほとんど な い 。
# どこ に 座 れ ば い い で す か 。
# 秘密 は 失敗 の こと で は 失敗 する こと で は な い 。
# 彼女 は ｏｌ で す 。
# 彼女 は 銀行 で 働 い て い る 。
# 彼 を 夜 まで に し て もら い ま す か 。
# で も 彼 の 名前 は よく 知 っ て い る 。
# スミス さん と 私 は 長 い 間 私 と 知り合い で す 。
# 彼 に は 多く の 世界 が 見え た 。
# 英語 を 話せ たら い い の に なあ 。
# 君 は 彼 の 手紙 に 返事 を 書 く べ き だっ た の に 。
# これ と あれ と で は どちら が 好き で す か 。
# 彼女 は 王 様 に は 乗 ら な い 。
# 彼 は 友人 と 握手 し た 。
# ちょっと 休 ん で も い い で す よ 。
# 何 か 新し い もの が 欲し い 。
# 彼 は この 前 会 っ た とき より 厳し い 。
# 私 は あなた と は まったく 同 意見 で は な い 。
# 私 は その 研究 と し て い ま す 。
# 早寝 早起き は 健康 に よ く な い 。
# 彼 は この 仕事 を 一人 で 終え た 。
# 彼 の 答え は 私 を だま さ れ た 。
# もし パーティー に 行 く よう に し て くださ い 。
# 彼 ら は 丘 の 下 に い た 。
# 英語 は 難し い で す ね 。
# みんな が 聞こえ る よう に 大きな 声 で ごらん 。
# 私 を 見 る と 彼女 は 私 に 言 わ な かっ た 。
# 彼女 は 風邪 で 寝込 ん で い る 。
# 失敗 を 恐れ る な 。
# 私 に 言 っ た こと は 決して 忘れ ま せ ん 。
# 彼 は 、 助け を 求め て い る 。
# 彼 は 本当 に 好き だ 。
# 馬 の 馬 は とても 楽し い 。
# 私 が 出かけ た 時 は 雨 で す 。
# 私 の 姉 は 今 仕事 に 精通 し て い る 。
# 電話 は 誰 も 働 い て い な い 。
# 私 達 は 野球 を し た 。
# 日本 の 人口 は 日本 人 で す か 。
# 私 達 は かばん で その 試合 を 考え た 。
# 私 は もう あの 男 に 同意 でき な い 。
# 他 に 他 に 人 に でき ま す か 。
# 彼女 は 幽霊 を 見 る よう な 気分 だっ た 。
# 君 に この こと を 言 っ て も い い で す よ 。
# ローラ が き た が 、 長 く な っ た 。
# 君 の 答え と トム の 答え と 比較 し なさ い 。
# はさみ を くださ い 。
# 今朝 は いつ も よ り 遅 く 起き た 。
# これ が みんな の 中 で 一番 ひど い 。
# 今日 は 夕食 を 作 ろ う か 。
# 彼 は 群衆 を かき分け て 進 ん だ 。
# 誰 か が 隣 の 部屋 で 話 す の が 聞こえ る 。
# 税金 は どこ で す か 。
# 彼女 は 部屋 の 中 で 窓 を 全部 閉め た 。
# 私 は トマト が 好き で は な い 。
# 小銭 は あ り ま す か 。
# 健康 ほど 貴重 な もの は な い 。
# 私 は 昨晩 その 本 を 読み 終え た 。
# 君 の 息子 は 、 その 学生 の 方 に 参加 し た 。
# 私 は スポーツ が 大好き で す 。
# 彼 の 助け なし で 済ま す 。
# 君 は そんな に 早 く 起き る 必要 は な い 。
# 彼 は 英語 と フランス 語 を 話せ る 。
# 与え る 価値 が あ れ ば 、 悪 く する 。
# 彼 は 中 に 入 っ た 。
# ぜひ 行 っ て くださ い 。
# 彼女 は 涙 を 流 そ う と し な かっ た 。
# その 話 は 彼女 に しみじみ と 感 じ られ た 。
# 彼女 は 自分 の 新し い 服 に 満足 し て い た 。
# 彼 は ここ に 数 週間 滞在 する だ ろ う 。
# 彼 ら は 忙し かっ た 。
# 私 は その 時 駅 まで 歩 い て い た 。
# 私 達 は 道路 に そ っ て 歩 い た 。
# 彼女 に 電話 を かけ る なら 最後 だ ろ う 。
# 車 の 前 で その 車 は ちょうど 私 の 前 に あ っ た 。
# その 少女 たち は 互い に 頭 が い い 。
# お 金 は 自由 に 買え な い 。
# 今日 は 宿題 が な い 。
# この 古 い 上着 は 届 い た 。
# バケツ に は ほとんど 水 が な い 。
# 困難 に 陥 っ た とき 彼 は 両親 に 助け を 求め た 。
# 太陽 が 雲 の 中 に 入 っ た 。
# 彼 の 話 は 全く 試合 に な っ た 。
# よく あ る こと だ ろ う 。
# 彼女 は 先生 が 入 っ て き た とき 立ち上が っ た 。
# 彼 は トマト が 好き だ 。
# 雨 は 炎上 し た 。
# この 雨 に 乗 る な 。
# 車 で あなた の 家 に 迎え に 行 き ま す 。
# 知 ら せ て くださ い 。
# 私 は 事態 を 確信 し ま す 。
# それ は 我々 の お 楽しみ で す 。
# それ は や る 価値 が あ る と 思 う 。
# 彼 は 演説 を し て い る 。
# いつ も この 辞書 を 使 い ま す 。
# 来週 彼 は 商用 で ニューヨーク へ 行 く 。
# その 子 は 母親 に その 赤ん坊 を うけ た 。
# 彼 は 怒 っ た 男 を なだめ よ う と し た 。
# 彼 は 本 を 選 び た い 。
# 私 の 言 う とおり に し なさ い 。
# その 本 を どけ て 下さ い 。
# 彼女 は それ を 聞 い たら 泣 い た 。
# 今 は 英語 の 宿題 を し 終え た ところ だ 。
# 私 は 絶対 に お 金 を 借り な い 。
# 健 は 去年 日本 に い ま し た 。
# 彼 は 先月 から ずっと 病気 だっ た そう だ 。
# あなた は 来週 試験 に 座 り ま す か 。
# 彼女 は 明かり を 消 し た 。
# 私 は 時々 彼 に 会 う 。
# 私 は 彼女 に パーティー に 行け る か どう か 尋ね た 。
# 食べ 過ぎ な い で 下さ い 。
# 私 は とても 寒 い 。
# 私 は 仕事 を 終え る ため に 努力 し た 。
# 私 は 本 が ほし い 。
# それ は 行 く で しょ う 。
# 私 は その 質問 に 答え る こと が でき る 。
# 少し 待 っ て いただけ ま せ ん か 。
# 君 は 自分 で それ を 持 っ て き た 。
# いつ まで 日本 に 滞在 し ま す か 。
# 私 は この 問題 を 解け ま す 。
# 彼女 は 彼 に 反対 し た 。
# 彼 の 作文 は 誤り が な かっ た 。
# 私 たち は 旅行 の 途中 で 互い に 知り合い に な っ た 。
# 私 は 彼 と 連絡 を 取 り た い 。
# 私 が そこ に 行 く 必要 は あ り ま す か 。
# 私 に は 頼れ る ところ が な い 。
# 彼 は その 少女 に 行 っ て い ま す 。
# みんな は 野球 を する の が 好き だ 。
# 中 に 入れ て は いけ な い 。
# 私 は 待 っ た が 、 待 っ た 。
# 病気 の ため 彼女 は 来 られ な かっ た 。
# 私 は 即金 で 時計 を 買 っ た 。
# 彼 の 自転 車 は 青 い 。
# この ドア は どう し て も 閉ま ら な い 。
# 我々 は この こと を 全体 的 に 考え な けれ ば な ら な い 。
# 君 は 戦争 に 合 い ま す か それ と 反対 で す か 。
# それ に つ い て 彼 が 言 う こと を 忘れ て い る 。
# 彼 は 毎朝 は 散歩 に 出かけ る と 言 っ た 。
# 私 は その 知らせ に びっくり し た 。
# ここ から 東京 まで どの くらい 離れ て い ま す か 。
# ごめん 、 そう い わ な かっ たら い い けど 。
# 私 は 今夕 空港 に 着 い た 。
# 彼 は 言 わ な い と 約束 し た 。
# 彼 は 年 の 割 に は 若 く 見え る 。
# 彼 ら は 私 を 一人 で そこ へ 行 か せ た 。
# こしょう を 知 ら せ て くださ い 。
# 全く あなた の 言 う とおり で す ね 。
# 彼 は 仕事 を 終え た 後 で 就寝 し た 。
# 私 の 姉 は 毎朝 髪 を 洗 う 。
# この 辺 で 手伝 っ て 下さ い 。
# 私 は 彼 の こと は 気 に し な い 。
# あれ より も 良 い もの は な い 。
# これ で 間に合 う で しょ う 。
# それ が い い と 思 い ま す 。
# 彼女 に は 医者 は い る 息子 が い る 。
# 先生 は 答案 を 調べ た 。
# 彼 は その 列車 に 乗 る ため に 幸運 に な っ た 。
# 私 は 歩 い て い き ま す 。
# 彼女 は 私 が 遅れ た こと が 大好き だっ た 。
# で も 食べ な い で 下さ い 。
# 私 は あなた を 援助 し ま す 。
# 私 は 昨日 川 へ 魚釣り に 行 っ た 。
# 駅 に 行 っ て き た ところ で す 。
# 彼 は その 箱 に かさ を 入れ た 。
# これ が 本 で す 。
# 彼 は 一人 で テーブル を つけ た 。
# 雨 の 前 に 学校 に 着 い た 。
# その 国 は 戦争 で 分裂 し て い た 。
# この 歌 は 私 に よく 知 ら れ て い る 。
# 正し い もの は 正し い 。
# 部屋 は 掃除 し ま し た か 。
# 彼 は テニス が うま い 。
# 彼 は 他人 の 悪口 を 言 う 人 で は な い 。
# 道 を 地図 で いただけ ま す か 。
# 私 は 彼 の 言 う こと が 何 で も 理解 でき な い 。
# その 騒音 に は 口 を 出 す 時間 が 長 く な っ た 。
# 君 は そんな こと を 言 う べ き で は な い 。
# これ ら は 何 と い う 世の中 な 本 で す 。
# 彼 は 努力 し た が 成功 し な かっ た 。
# どこ から 来 ま し た か 。

# %% [markdown]
# ## 宿題1
# デコード時のbeam幅を変更し翻訳性能の変化を確認してください。

# %%
# !onmt_translate --model tanaka-model_step_20000.pt --src small_parallel_enja/test.en --output pred.txt --replace_unk --verbose

# %% [markdown]
# ## 宿題2
# 学習時のパラメータを変更し翻訳性能の改善を試してみてください。

# %% [markdown]
# # 自己注意型NMT（transformer）

# %% [markdown]
# ## 学習
# onmt_train というコマンドでtransformerを指定して学習します。
# --world_sizeで使う GPU の個数を1に、--gpu_ranksで使う GPUを0指定します。
# --encoder_type transformerと--decoder_type transformerでエンコーダとデコーダの種類をtransformerに指定します。
# -position_encodingでposition encodingと指定します。
# --train_steps は学習するステップを指定します。20,000だとこのデータは40分くらいで学習できます。
# 他のパラメータはtransformerの性能を出すためのディフォルト設定です。

# %%
# !onmt_train --data data/tanaka --save_model tanaka-model-transformer  \
        -layers 6 -rnn_size 512 -word_vec_size 512 -transformer_ff 2048 -heads 8  \
        -encoder_type transformer -decoder_type transformer -position_encoding \
        -train_steps 20000  -max_generator_batches 2 -dropout 0.1 \
        -batch_type tokens -normalization tokens  -accum_count 2 \
        -optim adam -adam_beta2 0.998 -decay_method noam -warmup_steps 8000 -learning_rate 2 \
        -max_grad_norm 0 -param_init 0  -param_init_glorot \
        -label_smoothing 0.1 -save_checkpoint_steps 10000 \
        -world_size 1 -gpu_ranks 0

# %% [markdown]
# ## 翻訳モデル
# 学習されたモデルは tanaka-model-transformer_step_20000.pt のような名前で保存されています。

# %%
ls -l

# %% [markdown]
# ## デコード
# onmt_translate というスクリプトでデコードします。一つ前に学習した翻訳モデルのうちの1つを指定します。
# --output pred.txt というので結果を保存するファイルを指定します。
# --replace_unk というのは未知語処理をするというオプションです。
# --verbose は結果を冗長に画面にも表示させるオプションです。

# %%
# !onmt_translate --model tanaka-model-transformer_step_20000.pt --src small_parallel_enja/test.en --output pred-transformer.txt --replace_unk --verbose

# %% [markdown]
# ##BLEU による評価
# 正解（参照訳）のファイルを第一引数に、システムの出力をリダイレクト（<）で渡します。

# %%
# !perl tools/multi-bleu.perl small_parallel_enja/test.ja < pred-transformer.txt

# %% [markdown]
# 性能出ない理由は学習が足りないからです。-batch_type tokensデフォルト-batch_size 64 は1 step 64 tokenつまり4文ぐらいで、20000 stepですと4×20000/50000=1.6 epochしか学習していません。一方RNNの場合は1 step 64文で、20000 stepですと64×20000/50000=25.6 epoch学習しています。

# %%
cat pred-transformer.txt
